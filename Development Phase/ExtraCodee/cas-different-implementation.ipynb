# %%
class Instruction:
    def __init__(self, instruction):
        self.instructionVal = bin(instruction)
        self.opcode = instruction >> 26 & 0b111111
        self.rs = instruction >> 21 & 0b11111
        self.rt = instruction >> 16 & 0b11111
        self.rd = instruction >> 11 & 0b11111
        self.shamt = instruction >> 6 & 0b11111
        self.funct = instruction & 0b111111
        self.imm = instruction & 0xFFFF
        self.cycles = [0] * 5 #creates an array for every stage to record at which stage was an instruction in every cycle
                                #for example, if an instruction was at Decode stage, then self.cycles[0] = 0 and self.cycoles[1] = 1 and so on... a dictionary might be better.

# %%
class PipelineState:
    def __init__(self):
        self.cycle = 0
        self.ifidFlush = 0
        self.idexFlush = 0
        self.ifidStall = 0
        self.notEqual = 1
        self.equal = 0
        self.pc = 0
        self.registers = [0] *32
        self.memory = [0] * 1024 #can be changed to any size depending on the memory size

# %%
class PipelineRegister:
    def __init__(self):
        self.flush = 0
        self.instruction = 0
        self.instructionVal = 0
        self.data = 0 # any data, depending on the stage. signals are interpreted directly w/o a CU so no need for multiple signals 
        self.done = 0
        self.flush = 0
        self.pc = 0

# %%
instructions = []
with open("imem.txt", 'r') as inst:
    for line in inst:
        parts = line.split(":")
        if len(parts)>1:
            instructions.append(int(parts[1].strip().rstrip(";"),2))

# %%
IF_ID = PipelineRegister()
ID_EX = PipelineRegister()
EX_MEM = PipelineRegister()
MEM_WB = PipelineRegister()
opcodes = {
    0x0 : 'rtype', 0x8: 'addi', 0xd :'ori', 0xe: 'xori', 0xc:'andi', 0xa:'slti',
    0x23: 'lw', 0x2b : 'sw', 0x4:'beq', 0x2:'j', 0x3 : 'jal', 0x5:'bne'
      
}
notWrites = [0x2b, 0x4, 0x2, 0x5]
rtypes = {
    0x20: 'add', 0x22:'sub', 0x24:'and', 0x25: 'or', 0x2a:'slt', 0x26: 'xor', 
    0x27:'nor', 0x0:'sll', 0x2:'srl', 0x8:'jr'
    
}
def signed(data):
        if data & 0x8000:
            return data - (1 << 16)  
        else: return data

# %%
def hazard_unit(ID_EX, state, EX_MEM, MEM_WB):
    branchHazard = False
    if not EX_MEM.done and MEM_WB.done and ID_EX.done:
        op1, op2 = forwarding_unit(EX_MEM, MEM_WB, ID_EX)
        print("HDU comparator operands:\n")
        print("op1: ", op1, "     op2: ", op2)
        if opcodes[ID_EX.instruction.opcode] == 'bne' and  (op1 == op2):
            branchHazard = True
        elif opcodes[ID_EX.instruction.opcode] == 'beq' and (op1 != op2):
            branchHazard = True
        else: branchHazard = False
    return branchHazard

# %%
def forwarding_unit(EX_MEM, MEM_WB, ID_EX):
    if not EX_MEM.done and MEM_WB.done and ID_EX.done:
        writeex = 1 if EX_MEM.instruction.opcode not in notWrites else 0
        writewb = 1 if MEM_WB.instruction.opcode not in notWrites else 0
        if writeex and EX_MEM.destreg == ID_EX.rs and EX_MEM.destreg != 0:
            op1 = EX_MEM.data 
        elif writewb and MEM_WB.destreg == ID_EX.rs and MEM_WB.destreg !=0:
            op1 = MEM_WB.data
        else: op1 = state.registers[ID_EX.instruction.rs]

        if writeex and EX_MEM.destreg == ID_EX.rt and MEM_WB.destreg !=0:
            op2 = EX_MEM.data
        elif writewb and MEM_WB.destreg == ID_EX.rt:
            op2 = MEM_WB.data
        else: op2 = state.registers[ID_EX.instruction.rt]
        return op1, op2
    else: return state.registers[ID_EX.instruction.rs], state.registers[ID_EX.instruction.rt]

# %%
state = PipelineState()
def fetch(state, instructions, IF_ID):
    if IF_ID.done:
        return
    elif state.ifidFlush:
        IF_ID.instruction = Instruction(0)
        IF_ID.instructionVal = 0
        inst = Instruction(0)
    else:
        if state.pc < len(instructions):
            inst = Instruction(instructions[state.pc])
        else: inst = Instruction(0)
        inst.cycles[0] = 1
        IF_ID.instruction = inst
        IF_ID.instructionVal = inst.instructionVal
        IF_ID.pcp1 = state.pc +1
        if opcodes[inst.opcode] == 'beq' or opcodes[inst.opcode] =='bne':
            state.pc = state.pc +1+ signed(inst.imm )& 0b1111111111
        elif opcodes[inst.opcode] == 'j' or opcodes[inst.opcode] =='jal':
            state.pc = inst.imm &0b1111111111
        elif opcodes[inst.opcode] == 'rtype' and rtypes[inst.funct] == 'jr':
            state.pc = state.registers[inst.rs] & 0b1111111111
        else: 
             state.pc += 1
    IF_ID.pc = state.pc
    IF_ID.done = 1

# %%
def decode(state, IF_ID, ID_EX):
    ID_EX.readData1 = 0
    ID_EX.readData2 = 0
    ID_EX.imm = 0
    ID_EX.rs = 0
    ID_EX.rt = 0
    ID_EX.rd = 0
    ID_EX.pcp1 = 0
    ID_EX.instruction = Instruction(0)
    if not IF_ID.done: #checks if IFID is fetching another instruction or not
        return
    
    inst = IF_ID.instruction
    inst.cycles[0] = 0
    inst.cycles[1] = 1
    inst.cycles[2] = 0
    inst.cycles[3] = 0
    if state.idexFlush:
        ID_EX.instruction = Instruction(0)
        ID_EX.instructionVal = 0
        inst = Instruction(0)
    
    if opcodes[inst.opcode] == 'rtype':
        ID_EX.readData1 = state.registers[inst.rs]
        ID_EX.readData2 = state.registers[inst.rt]
    else:
        ID_EX.imm = signed(inst.imm)
        ID_EX.readData1 = state.registers[inst.rs]
    ID_EX.instruction = inst
    ID_EX.instructionVal = inst.instructionVal
    ID_EX.rs = inst.rs
    ID_EX.rt = inst.rt
    ID_EX.rd = inst.rd
    ID_EX.pc = IF_ID.pc
    ID_EX.pcp1 = IF_ID.pcp1
    ID_EX.done = 1 #IDEX cannot decode and change its value until execute stage is done
    IF_ID.done = 0 # IFID is now allowed to fetch another instruction

# %%
def execute(state,ID_EX, EX_MEM):
    if not ID_EX.done: #checks if IDEX is decoding another instruction or not
        return
    
    EX_MEM.forwardBres = 0
    EX_MEM.imm = 0
    EX_MEM.readData1 = 0
    inst = ID_EX.instruction
    inst.cycles[0] = 0
    inst.cycles[1] = 0
    inst.cycles[2] = 1
    inst.cycles[3] = 0
    validRt = opcodes[inst.opcode] == 'rtype' or opcodes[inst.opcode] =='bne' or opcodes[inst.opcode] == 'beq'
    op1, op2 = forwarding_unit(EX_MEM, MEM_WB, ID_EX)
    if not validRt: op2 = ID_EX.imm
    if opcodes[inst.opcode] == 'rtype':
        if rtypes[inst.funct] =='add':
            EX_MEM.data = op1 + op2
        elif rtypes[inst.funct] =='sub':
            EX_MEM.data = op1 - op2
        elif rtypes[inst.funct] =='and':
            EX_MEM.data = op1 & op2
        elif rtypes[inst.funct] =='or':
            EX_MEM.data = op1 | op2
        elif rtypes[inst.funct] =='slt':
            EX_MEM.data = 1 if op1<op2 else 0
        elif rtypes[inst.funct] =='xor':
            EX_MEM.data = op1 ^ op2
        elif rtypes[inst.funct] =='nor':
            EX_MEM.data = ~(op1 | op2)
        elif rtypes[inst.funct] =='sll':
            EX_MEM.data = op1 <<inst.shamt
        elif rtypes[inst.funct] =='srl':
            EX_MEM.data = op1 >> inst.shamt
    elif opcodes[inst.opcode] == 'addi':
        EX_MEM.data = op1+op2
    elif opcodes[inst.opcode] == 'ori':
        EX_MEM.data = op1|op2
    elif opcodes[inst.opcode] == 'xori':
        EX_MEM.data = op1^op2
    elif opcodes[inst.opcode] == 'andi':
        EX_MEM.data = op1&op2
    elif opcodes[inst.opcode] == 'slti':
        EX_MEM.data = 1 if op1<op2 else 0
    else: EX_MEM.data = 0
    state.notEqual = op1-op2
    state.equal = not state.notEqual
    EX_MEM.instruction = inst
    EX_MEM.instructionVal = inst.instructionVal
    EX_MEM.imm = ID_EX.imm
    EX_MEM.readData1 = ID_EX.readData1
    EX_MEM.rs = inst.rs
    EX_MEM.rt = inst.rt
    EX_MEM.rd = inst.rd
    EX_MEM.op1 = op1
    EX_MEM.op2 = op2
    EX_MEM.destreg = inst.rd if validRt else inst.rt
    EX_MEM.pcp1 = ID_EX.pcp1
    EX_MEM.pc = ID_EX.pc
    EX_MEM.done = 1
    ID_EX.done = 0

# %%
def memory (state, EX_MEM, MEM_WB):
    if not EX_MEM.done: #checks if exeucte is executing or not
        return
    inst = EX_MEM.instruction
    inst.cycles[0] = 0
    inst.cycles[1] = 0
    inst.cycles[2] = 0
    inst.cycles[3] = 1
    MEM_WB.data = EX_MEM.data
    if opcodes[inst.opcode] == 'lw':
        state.memory[EX_MEM.forwardBres + EX_MEM.imm] = EX_MEM.readData1
    elif opcodes[inst.opcode] == 'sw':
        MEM_WB.data = state.memory[EX_MEM.forwardBres + EX_MEM.imm]
    
    MEM_WB.instruction = inst
    MEM_WB.instructionVal = inst.instructionVal
    MEM_WB.rs = inst.rs
    MEM_WB.rt = inst.rt
    MEM_WB.rd = inst.rd
    MEM_WB.destreg = EX_MEM.destreg
    MEM_WB.pc = EX_MEM.pc
    MEM_WB.done = 1
    EX_MEM.done =0

# %%
opcodes = {
    0x0 : 'rtype', 0x8: 'addi', 0xd :'ori', 0xe: 'xori', 0xc:'andi', 0xa:'slti',
    0x23: 'lw', 0x2b : 'sw', 0x4:'beq', 0x2:'j', 0x3 : 'jal', 0x5:'bne'
      
}


def writeBack(state, MEM_WB):
    if not MEM_WB.done:
        return
    inst = MEM_WB.instruction
    inst.cycles[0] = 0
    inst.cycles[1] = 0
    inst.cycles[2] = 0
    inst.cycles[3] = 0
    inst.cycles[4] = 1
    if opcodes[inst.opcode] != 'sw' and opcodes[inst.opcode] !='j' and opcodes[inst.opcode] !='jal' and opcodes[inst.opcode] !='bne' and opcodes[inst.opcode] !='beq':
        state.registers[inst.rd if opcodes[inst.opcode] == 'rtype' else inst.rt] = MEM_WB.data
    MEM_WB.done = 0

# %%
cycle = 0
cycles = 25
stages = {'IF_ID':IF_ID, 'ID_EX':ID_EX, 'EX_MEM':EX_MEM, 'MEM_WB':MEM_WB}
while (cycle < cycles):
    
        
    writeBack(state, MEM_WB)
    memory(state, EX_MEM, MEM_WB)
    branchHazard = hazard_unit(ID_EX, state, EX_MEM, MEM_WB)
    if branchHazard:
        state.pc = ID_EX.pcp1
        state.ifidFlush = 1
        state.idexFlush = 1
        print("flush detected")
    else:
        state.ifidFlush = 0
        state.idexFlush = 0 
    execute(state, ID_EX, EX_MEM)
    decode(state, IF_ID, ID_EX)
    fetch(state, instructions, IF_ID)
    
    print(f"\n{'-' *50}")
    print(f"Cycle {cycle}")
    print(f"{'-'*50}")
    print(f"PC: {state.pc}")
    #pipeline register states
    for stage, reg in stages.items():
        print(f"{stage}: \n")
        for signal, value in vars(reg).items():
            print(f"{signal}: {value}")
        print("-"*20)
    cycle +=1
state.pc = 0
def print_registers(registers):
    print("\nFinal Register Values:")
    print(f"{'-' * 50}")
    for i, value in enumerate(registers):
        print(f"R{i:2}: {value}")
    print(f"{'-' * 50}\n")

print_registers(state.registers[0:15])
# Out:
# --------------------------------------------------
# Cycle 0
# --------------------------------------------------
# PC: 1
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b100000000000011111111111111011
# data: 0
# done: 1
# pc: 1
# pcp1: 1
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0
# data: 0
# done: 0
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: 0
# instructionVal: 0
# data: 0
# done: 0
# pc: 0
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: 0
# instructionVal: 0
# data: 0
# done: 0
# pc: 0
# --------------------
#
# --------------------------------------------------
# Cycle 1
# --------------------------------------------------
# PC: 2
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b100000000000100000000000000101
# data: 0
# done: 1
# pc: 2
# pcp1: 2
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b100000000000011111111111111011
# data: 0
# done: 1
# pc: 1
# readData1: 0
# readData2: 0
# imm: -5
# rs: 0
# rt: 1
# rd: 31
# pcp1: 1
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: 0
# instructionVal: 0
# data: 0
# done: 0
# pc: 0
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: 0
# instructionVal: 0
# data: 0
# done: 0
# pc: 0
# --------------------
#
# --------------------------------------------------
# Cycle 2
# --------------------------------------------------
# PC: 3
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b100000000000110000000000000101
# data: 0
# done: 1
# pc: 3
# pcp1: 3
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b100000000000100000000000000101
# data: 0
# done: 1
# pc: 2
# readData1: 0
# readData2: 0
# imm: 5
# rs: 0
# rt: 2
# rd: 0
# pcp1: 2
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b100000000000011111111111111011
# data: -5
# done: 1
# pc: 1
# forwardBres: 0
# imm: -5
# readData1: 0
# rs: 0
# rt: 1
# rd: 31
# op1: 0
# op2: -5
# destreg: 1
# pcp1: 1
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: 0
# instructionVal: 0
# data: 0
# done: 0
# pc: 0
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 3
# --------------------------------------------------
# PC: 4
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b100000000000000000000000000000
# data: 0
# done: 1
# pc: 4
# pcp1: 4
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b100000000000110000000000000101
# data: 0
# done: 1
# pc: 3
# readData1: 0
# readData2: 0
# imm: 5
# rs: 0
# rt: 3
# rd: 0
# pcp1: 3
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b100000000000100000000000000101
# data: 5
# done: 1
# pc: 2
# forwardBres: 0
# imm: 5
# readData1: 0
# rs: 0
# rt: 2
# rd: 0
# op1: 0
# op2: 5
# destreg: 2
# pcp1: 2
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b100000000000011111111111111011
# data: -5
# done: 1
# pc: 1
# rs: 0
# rt: 1
# rd: 31
# destreg: 1
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 4
# --------------------------------------------------
# PC: 5
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b100000000000000000000000000000
# data: 0
# done: 1
# pc: 5
# pcp1: 5
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b100000000000000000000000000000
# data: 0
# done: 1
# pc: 4
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 4
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b100000000000110000000000000101
# data: 5
# done: 1
# pc: 3
# forwardBres: 0
# imm: 5
# readData1: 0
# rs: 0
# rt: 3
# rd: 0
# op1: 0
# op2: 5
# destreg: 3
# pcp1: 3
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b100000000000100000000000000101
# data: 5
# done: 1
# pc: 2
# rs: 0
# rt: 2
# rd: 0
# destreg: 2
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 5
# --------------------------------------------------
# PC: 8
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b10000011000100000000000000010
# data: 0
# done: 1
# pc: 8
# pcp1: 6
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b100000000000000000000000000000
# data: 0
# done: 1
# pc: 5
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 5
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b100000000000000000000000000000
# data: 0
# done: 1
# pc: 4
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 4
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b100000000000110000000000000101
# data: 5
# done: 1
# pc: 3
# rs: 0
# rt: 3
# rd: 0
# destreg: 3
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 6
# --------------------------------------------------
# PC: 6
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b10000011000101111111111111101
# data: 0
# done: 1
# pc: 6
# pcp1: 9
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b10000011000100000000000000010
# data: 0
# done: 1
# pc: 8
# readData1: 5
# readData2: 0
# imm: 2
# rs: 3
# rt: 2
# rd: 0
# pcp1: 6
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b100000000000000000000000000000
# data: 0
# done: 1
# pc: 5
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 5
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b100000000000000000000000000000
# data: 0
# done: 1
# pc: 4
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  5      op2:  5
#
# --------------------------------------------------
# Cycle 7
# --------------------------------------------------
# PC: 7
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b100000000001000000000000010111
# data: 0
# done: 1
# pc: 7
# pcp1: 7
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b10000011000101111111111111101
# data: 0
# done: 1
# pc: 6
# readData1: 5
# readData2: 0
# imm: -3
# rs: 3
# rt: 2
# rd: 31
# pcp1: 9
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b10000011000100000000000000010
# data: 0
# done: 1
# pc: 8
# forwardBres: 0
# imm: 2
# readData1: 5
# rs: 3
# rt: 2
# rd: 0
# op1: 5
# op2: 5
# destreg: 0
# pcp1: 6
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b100000000000000000000000000000
# data: 0
# done: 1
# pc: 5
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  5      op2:  5
#
# --------------------------------------------------
# Cycle 8
# --------------------------------------------------
# PC: 9
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b1000000000000000000000001001
# data: 0
# done: 1
# pc: 9
# pcp1: 8
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b100000000001000000000000010111
# data: 0
# done: 1
# pc: 7
# readData1: 0
# readData2: 0
# imm: 23
# rs: 0
# rt: 4
# rd: 0
# pcp1: 7
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b10000011000101111111111111101
# data: 0
# done: 1
# pc: 6
# forwardBres: 0
# imm: -3
# readData1: 5
# rs: 3
# rt: 2
# rd: 31
# op1: 5
# op2: 5
# destreg: 31
# pcp1: 9
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b10000011000100000000000000010
# data: 0
# done: 1
# pc: 8
# rs: 3
# rt: 2
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 9
# --------------------------------------------------
# PC: 10
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b100000000000000000000000000000
# data: 0
# done: 1
# pc: 10
# pcp1: 10
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b1000000000000000000000001001
# data: 0
# done: 1
# pc: 9
# readData1: 0
# readData2: 0
# imm: 9
# rs: 0
# rt: 0
# rd: 0
# pcp1: 8
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b100000000001000000000000010111
# data: 23
# done: 1
# pc: 7
# forwardBres: 0
# imm: 23
# readData1: 0
# rs: 0
# rt: 4
# rd: 0
# op1: 0
# op2: 23
# destreg: 4
# pcp1: 7
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b10000011000101111111111111101
# data: 0
# done: 1
# pc: 6
# rs: 3
# rt: 2
# rd: 31
# destreg: 31
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 10
# --------------------------------------------------
# PC: 11
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b10001000010100000100010
# data: 0
# done: 1
# pc: 11
# pcp1: 11
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b100000000000000000000000000000
# data: 0
# done: 1
# pc: 10
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 10
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b1000000000000000000000001001
# data: 0
# done: 1
# pc: 9
# forwardBres: 0
# imm: 9
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 9
# destreg: 0
# pcp1: 8
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b100000000001000000000000010111
# data: 23
# done: 1
# pc: 7
# rs: 0
# rt: 4
# rd: 0
# destreg: 4
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 11
# --------------------------------------------------
# PC: 12
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 12
# pcp1: 12
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b10001000010100000100010
# data: 0
# done: 1
# pc: 11
# readData1: 5
# readData2: 23
# imm: 0
# rs: 2
# rt: 4
# rd: 5
# pcp1: 11
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b100000000000000000000000000000
# data: 0
# done: 1
# pc: 10
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 10
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b1000000000000000000000001001
# data: 0
# done: 1
# pc: 9
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  5      op2:  23
#
# --------------------------------------------------
# Cycle 12
# --------------------------------------------------
# PC: 13
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 13
# pcp1: 13
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 12
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 12
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b10001000010100000100010
# data: -18
# done: 1
# pc: 11
# forwardBres: 0
# imm: 0
# readData1: 5
# rs: 2
# rt: 4
# rd: 5
# op1: 5
# op2: 23
# destreg: 5
# pcp1: 11
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b100000000000000000000000000000
# data: 0
# done: 1
# pc: 10
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 13
# --------------------------------------------------
# PC: 14
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 14
# pcp1: 14
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 13
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 13
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 12
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 12
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b10001000010100000100010
# data: -18
# done: 1
# pc: 11
# rs: 2
# rt: 4
# rd: 5
# destreg: 5
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 14
# --------------------------------------------------
# PC: 15
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 15
# pcp1: 15
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 14
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 14
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 13
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 13
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 12
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 15
# --------------------------------------------------
# PC: 16
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3770>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 16
# pcp1: 16
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 15
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 15
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 14
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 14
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 13
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 16
# --------------------------------------------------
# PC: 17
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3a10>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 17
# pcp1: 17
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3770>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 16
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 16
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 15
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 15
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 14
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 17
# --------------------------------------------------
# PC: 18
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c6777b73020>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 18
# pcp1: 18
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3a10>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 17
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 17
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3770>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 16
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 16
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1460>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 15
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 18
# --------------------------------------------------
# PC: 19
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3860>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 19
# pcp1: 19
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c6777b73020>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 18
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 18
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3a10>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 17
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 17
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3770>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 16
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 19
# --------------------------------------------------
# PC: 20
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3ef0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 20
# pcp1: 20
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3860>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 19
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 19
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c6777b73020>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 18
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 18
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3a10>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 17
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 20
# --------------------------------------------------
# PC: 21
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e0fe0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 21
# pcp1: 21
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3ef0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 20
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 20
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3860>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 19
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 19
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c6777b73020>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 18
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 21
# --------------------------------------------------
# PC: 22
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 22
# pcp1: 22
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e0fe0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 21
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 21
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3ef0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 20
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 20
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3860>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 19
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 22
# --------------------------------------------------
# PC: 23
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1a30>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 23
# pcp1: 23
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 22
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 22
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e0fe0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 21
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 21
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3ef0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 20
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 23
# --------------------------------------------------
# PC: 24
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 24
# pcp1: 24
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1a30>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 23
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 23
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 22
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 22
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e0fe0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 21
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
# HDU comparator operands:
#
# op1:  0      op2:  0
#
# --------------------------------------------------
# Cycle 24
# --------------------------------------------------
# PC: 25
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e18e0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 25
# pcp1: 25
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e3cb0>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 24
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# pcp1: 24
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67740e1a30>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 23
# forwardBres: 0
# imm: 0
# readData1: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# destreg: 0
# pcp1: 23
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x7c67741c2e10>
# instructionVal: 0b0
# data: 0
# done: 1
# pc: 22
# rs: 0
# rt: 0
# rd: 0
# destreg: 0
# --------------------
#
# Final Register Values:
# --------------------------------------------------
# R 0: 0
# R 1: -5
# R 2: 5
# R 3: 5
# R 4: 23
# R 5: -18
# R 6: 0
# R 7: 0
# R 8: 0
# R 9: 0
# R10: 0
# R11: 0
# R12: 0
# R13: 0
# R14: 0
# --------------------------------------------------
