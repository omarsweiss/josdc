# %%
gsharebits = 0b1111111
gsharesize = 128
class Instruction:
    def __init__(self, instruction):
        self.instructionVal = bin(instruction)
        self.opcode = instruction >> 26 & 0b111111
        self.rs = instruction >> 21 & 0b11111
        self.rt = instruction >> 16 & 0b11111
        self.rd = instruction >> 11 & 0b11111
        self.shamt = instruction >> 6 & 0b11111
        self.funct = instruction & 0b111111
        self.imm = instruction & 0xFFFF
        self.cycles = [0] * 5 #creates an array for every stage to record at which stage was an instruction in every cycle
                                #for example, if an instruction was at Decode stage, then self.cycles[0] = 0 and self.cycoles[1] = 1 and so on... a dictionary might be better.

# %%
class PipelineState:
    def __init__(self):
        self.cycle = 0
        self.ifidFlush = 0
        self.idexFlush = 0
        self.histReg = 0
        self.pduStates = [0b00]*gsharesize
        self.ifidStall = 0
        self.pc = 0
        self.registers = [0] *32
        self.memory = [0] * 1024 #can be changed to any size depending on the memory size

# %%
class PipelineRegister:
    def __init__(self):
        self.flush = 0
        self.instruction = 0
        self.instructionVal = 0
        self.prediction = 0
        self.stateIndex = 0
        self.last = 0
        self.data = 0 # any data, depending on the stage. signals are interpreted directly w/o a CU so no need for multiple signals 
        self.done = 0
        self.flush = 0
        self.pc = 0

# %%
instructions = []
with open("imem.txt", 'r') as inst:
    for line in inst:
        parts = line.split(":")
        if len(parts)>1:
            instructions.append(int(parts[1].strip().rstrip(";"),2))

# %%
IF_ID = PipelineRegister()
ID_EX = PipelineRegister()
EX_MEM = PipelineRegister()
MEM_WB = PipelineRegister()
state = PipelineState()
state.memory[0] = 0x5
state.memory[1] = 0x7
state.memory[2] = 0x2
state.memory[3] = 0xF
state.memory[4] = 0xA
state.memory[5] = 0x10
state.memory[6] = 0x30
state.memory[7] = 0x1
state.memory[8] = 0xFF
state.memory[9] = 0x55
opcodes = {
    0x0 : 'rtype', 0x8: 'addi', 0xd :'ori', 0xe: 'xori', 0xc:'andi', 0xa:'slti',
    0x23: 'lw', 0x2b : 'sw', 0x4:'beq', 0x2:'j', 0x3 : 'jal', 0x5:'bne'
      
}
notWrites = [0x2b, 0x4, 0x2, 0x5]
rtypes = {
    0x20: 'add', 0x22:'sub', 0x24:'and', 0x25: 'or', 0x2a:'slt', 0x26: 'xor', 
    0x27:'nor', 0x0:'sll', 0x2:'srl', 0x8:'jr'
    
}
def signed(data):
        if data & 0x8000:
            return data - (1 << 16)  
        else: return data

# %%
def forwarding_unit(EX_MEM, MEM_WB, ID_EX, state):
    if not EX_MEM.done and MEM_WB.done and ID_EX.done:
        writeex = 1 if EX_MEM.instruction.opcode not in notWrites else 0
        writewb = 1 if MEM_WB.instruction.opcode not in notWrites else 0
        if writeex and EX_MEM.destreg == ID_EX.rs and EX_MEM.destreg != 0:
            op1 = EX_MEM.data 
        elif writewb and MEM_WB.destreg == ID_EX.rs and MEM_WB.destreg !=0:
            op1 = MEM_WB.data
        else: op1 = state.registers[ID_EX.instruction.rs]

        if writeex and EX_MEM.destreg == ID_EX.rt and MEM_WB.destreg !=0:
            op2 = EX_MEM.data
        elif writewb and MEM_WB.destreg == ID_EX.rt:
            op2 = MEM_WB.data
        else: op2 = state.registers[ID_EX.instruction.rt]
        return op1, op2
    else: return state.registers[ID_EX.instruction.rs], state.registers[ID_EX.instruction.rt]

# %%
def hazard_unit(ID_EX, state, EX_MEM, MEM_WB, IF_ID):
    ldHazard = False
    if IF_ID.done and ID_EX.done:
        memRead = opcodes[ID_EX.instruction.opcode] == 'lw'
        if memRead and ((IF_ID.rs == ID_EX.destreg) or (opcodes[IF_ID.instruction.opcode] == 'rtype' and (IF_ID.rt == ID_EX.destreg))):
            ldHazard = True
        else: ldHazard = False
    return ldHazard

# %%
def fetch(state, instructions, IF_ID):
    IF_ID.rs = 0
    IF_ID.rt = 0
    IF_ID.last = 0
    if IF_ID.done:
        return
    elif state.ifidFlush:
        IF_ID.instruction = Instruction(0)
        IF_ID.instructionVal = 0
        inst = Instruction(0)
    else:
        if state.pc < len(instructions):
            inst = Instruction(instructions[state.pc])
        else: 
            IF_ID.last = 1
            inst = Instruction(0)
        IF_ID.thisPC = state.pc
        inst.cycles[0] = 1
        IF_ID.instruction = inst
        IF_ID.instructionVal = inst.instructionVal
        stateIndex = ((state.histReg & gsharebits) ^ (state.pc & gsharebits))
        IF_ID.stateIndex = stateIndex
        prediction = ((state.pduStates[stateIndex] >> 1) &0b1)
        if ((opcodes[inst.opcode] == 'beq' or opcodes[inst.opcode] =='bne' )):
            IF_ID.prediction = prediction
            print("\nTAKEN" if prediction else "\n NOT TAKEN")
        IF_ID.rs = inst.rs
        IF_ID.rt = inst.rt
        IF_ID.pcp1 = state.pc +1
        if ((opcodes[inst.opcode] == 'beq' or opcodes[inst.opcode] =='bne' ) and prediction):
            state.pc = state.pc +1+ signed(inst.imm )& 0b1111111111
        elif opcodes[inst.opcode] == 'j' or opcodes[inst.opcode] =='jal':
            state.pc = inst.imm &0b1111111111
        elif opcodes[inst.opcode] == 'rtype' and rtypes[inst.funct] == 'jr':
            state.pc = state.registers[inst.rs] & 0b1111111111
        else: 
             state.pc += 1
            
    IF_ID.nextpc = state.pc
    IF_ID.done = 1

# %%
def decode(state, IF_ID, ID_EX):
    ID_EX.readData1 = 0
    ID_EX.readData2 = 0
    ID_EX.imm = 0
    ID_EX.last =0
    ID_EX.rs = 0
    ID_EX.rt = 0
    ID_EX.rd = 0
    ID_EX.thisPC = 0
    ID_EX.pcp1 = 0
    ID_EX.destreg = 0
    ID_EX.instruction = Instruction(0)
    if not IF_ID.done: #checks if IFID is fetching another instruction or not
        return
    
    inst = IF_ID.instruction
    inst.cycles[0] = 0
    inst.cycles[1] = 1
    inst.cycles[2] = 0
    inst.cycles[3] = 0
    if state.idexFlush:
        ID_EX.instruction = Instruction(0)
        ID_EX.instructionVal = 0
        inst = Instruction(0)
    
    if opcodes[inst.opcode] == 'rtype':
        ID_EX.readData1 = state.registers[inst.rs]
        ID_EX.readData2 = state.registers[inst.rt]
    else:
        ID_EX.imm = signed(inst.imm)
        ID_EX.readData1 = state.registers[inst.rs]
    ID_EX.instruction = inst
    ID_EX.prediction = IF_ID.prediction
    ID_EX.stateIndex = IF_ID.stateIndex
    ID_EX.instructionVal = inst.instructionVal
    ID_EX.rs = inst.rs
    ID_EX.rt = inst.rt
    validRt = opcodes[inst.opcode] == 'rtype' or opcodes[inst.opcode] =='bne' or opcodes[inst.opcode] == 'beq'
    ID_EX.destreg = inst.rd if validRt else inst.rt
    ID_EX.rd = inst.rd
    ID_EX.pcp1 = IF_ID.pcp1
    ID_EX.last = IF_ID.last
    ID_EX.thisPC = IF_ID.thisPC
    ID_EX.done = 1 #IDEX cannot decode and change its value until execute stage is done
    IF_ID.done = 0 # IFID is now allowed to fetch another instruction

# %%
def execute(state,ID_EX, EX_MEM):
    if not ID_EX.done: #checks if IDEX is decoding another instruction or not
        return
    EX_MEM.last =0
    EX_MEM.forwardBres = 0
    EX_MEM.imm = 0
    EX_MEM.readData1 = 0
    EX_MEM.instruction = Instruction(0)
    inst = ID_EX.instruction
    inst.cycles[0] = 0
    inst.cycles[1] = 0
    inst.cycles[2] = 1
    inst.cycles[3] = 0
    validRt = opcodes[inst.opcode] == 'rtype' or opcodes[inst.opcode] =='bne' or opcodes[inst.opcode] == 'beq'
    op1, op2 = forwarding_unit(EX_MEM=EX_MEM, MEM_WB=MEM_WB, ID_EX=ID_EX, state= state)
    if not validRt: op2 = ID_EX.imm
    if opcodes[inst.opcode] == 'rtype':
        if rtypes[inst.funct] =='add':
            EX_MEM.data = op1 + op2
        elif rtypes[inst.funct] =='sub':
            EX_MEM.data = op1 - op2
        elif rtypes[inst.funct] =='and':
            EX_MEM.data = op1 & op2
        elif rtypes[inst.funct] =='or':
            EX_MEM.data = op1 | op2
        elif rtypes[inst.funct] =='slt':
            EX_MEM.data = 1 if op1<op2 else 0
        elif rtypes[inst.funct] =='xor':
            EX_MEM.data = op1 ^ op2
        elif rtypes[inst.funct] =='nor':
            EX_MEM.data = ~(op1 | op2)
        elif rtypes[inst.funct] =='sll':
            EX_MEM.data = op1 <<inst.shamt
        elif rtypes[inst.funct] =='srl':
            EX_MEM.data = op1 >> inst.shamt
    elif opcodes[inst.opcode] == 'addi':
        EX_MEM.data = op1+op2
    elif opcodes[inst.opcode] == 'ori':
        EX_MEM.data = op1|op2
    elif opcodes[inst.opcode] == 'xori':
        EX_MEM.data = op1^op2
    elif opcodes[inst.opcode] == 'andi':
        EX_MEM.data = op1&op2
    elif opcodes[inst.opcode] == 'slti':
        EX_MEM.data = 1 if op1<op2 else 0
    elif opcodes[inst.opcode] == 'sw': EX_MEM.data = state.registers[inst.rt]
    else: EX_MEM.data = 0
    if(opcodes[inst.opcode] == 'bne'):
        if op1 == op2:
            taken = 0
        else: taken = 1
    elif(opcodes[inst.opcode] == 'beq'):
        if op1 == op2:
            taken = 1
        else: taken = 0
    else: taken = 0
    if((opcodes[inst.opcode] == 'bne') or (opcodes[inst.opcode] == 'beq')):
        state.histReg = (state.histReg << 1) + 1 if taken else  state.histReg << 1 
        if(taken):
            if state.pduStates[ID_EX.stateIndex] == 0b00:
                state.pduStates[ID_EX.stateIndex] == 0b01
            elif state.pduStates[ID_EX.stateIndex] == 0b01:
                state.pduStates[ID_EX.stateIndex] = 0b10
            elif state.pduStates[ID_EX.stateIndex] == 0b10:
                state.pduStates[ID_EX.stateIndex] = 0b11
            elif state.pduStates[ID_EX.stateIndex] == 0b11:
                state.pduStates[ID_EX.stateIndex] = 0b11
        else:
            if state.pduStates[ID_EX.stateIndex] == 0b00:
                state.pduStates[ID_EX.stateIndex] == 0b00
            elif state.pduStates[ID_EX.stateIndex] == 0b01:
                state.pduStates[ID_EX.stateIndex] = 0b00
            elif state.pduStates[ID_EX.stateIndex] == 0b10:
                state.pduStates[ID_EX.stateIndex] = 0b01
            elif state.pduStates[ID_EX.stateIndex] == 0b11:
                state.pduStates[ID_EX.stateIndex] = 0b10
    if opcodes[inst.opcode] == 'bne' or opcodes[inst.opcode] == 'beq':
        branchHazard = True if ID_EX.prediction ^ taken else False
        if branchHazard:
            if taken:
                state.pc = ID_EX.thisPC +1+ signed(inst.imm )& 0b1111111111
            else:
                state.pc = ID_EX.pcp1
            state.ifidFlush = 1
            state.idexFlush = 1
            print("flush detected")
        else:
            state.ifidFlush = 0
            state.idexFlush = 0
    EX_MEM.taken = taken                
    EX_MEM.instruction = inst
    EX_MEM.instructionVal = inst.instructionVal
    EX_MEM.imm = ID_EX.imm
    EX_MEM.readData1 = ID_EX.readData1
    EX_MEM.rs = inst.rs
    EX_MEM.rt = inst.rt
    EX_MEM.rd = inst.rd
    EX_MEM.op1 = op1
    EX_MEM.op2 = op2
    EX_MEM.last = ID_EX.last
    EX_MEM.thisPC = ID_EX.thisPC
    EX_MEM.destreg = inst.rd if validRt else inst.rt
    EX_MEM.pcp1 = ID_EX.pcp1
    EX_MEM.done = 1
    ID_EX.done = 0

# %%
def memory (state, EX_MEM, MEM_WB):
    MEM_WB.last =0
    if not EX_MEM.done: #checks if exeucte is executing or not
        return
    inst = EX_MEM.instruction
    inst.cycles[0] = 0
    inst.cycles[1] = 0
    inst.cycles[2] = 0
    inst.cycles[3] = 1
    MEM_WB.data = EX_MEM.data
    if opcodes[inst.opcode] == 'lw':
         MEM_WB.data = state.memory[EX_MEM.op1 + EX_MEM.imm]
    elif opcodes[inst.opcode] == 'sw':
        state.memory[EX_MEM.op1 + EX_MEM.imm] = MEM_WB.data
    
    MEM_WB.instruction = inst
    MEM_WB.instructionVal = inst.instructionVal
    MEM_WB.rs = inst.rs
    MEM_WB.rt = inst.rt
    MEM_WB.rd = inst.rd
    MEM_WB.last = EX_MEM.last
    MEM_WB.thisPC = EX_MEM.thisPC
    MEM_WB.destreg = EX_MEM.destreg
    MEM_WB.done = 1
    EX_MEM.done =0

# %%
opcodes = {
    0x0 : 'rtype', 0x8: 'addi', 0xd :'ori', 0xe: 'xori', 0xc:'andi', 0xa:'slti',
    0x23: 'lw', 0x2b : 'sw', 0x4:'beq', 0x2:'j', 0x3 : 'jal', 0x5:'bne'
      
}


def writeBack(state, MEM_WB):
    if not MEM_WB.done:
        return
    inst = MEM_WB.instruction
    inst.cycles[0] = 0
    inst.cycles[1] = 0
    inst.cycles[2] = 0
    inst.cycles[3] = 0
    inst.cycles[4] = 1
    if opcodes[inst.opcode] != 'sw' and opcodes[inst.opcode] !='j' and opcodes[inst.opcode] !='jal' and opcodes[inst.opcode] !='bne' and opcodes[inst.opcode] !='beq':
        state.registers[inst.rd if opcodes[inst.opcode] == 'rtype' else inst.rt] = MEM_WB.data
    MEM_WB.done = 0

# %%
def printState(stages):
    for stage, reg in stages.items():
            print(f"{stage}: \n")
            for signal, value in vars(reg).items():
                print(f"{signal}: {value}")
            print("-"*20)

# %%
cycle = 0
cycles = 5000
stages = {'IF_ID':IF_ID, 'ID_EX': ID_EX, 'EX_MEM': EX_MEM, 'MEM_WB': MEM_WB }
while (cycle < cycles):
    print(f"\n\n{'-' *50}")
    print(f"Cycle {cycle}")
    print(f"{'-'*50}")
    print(f"PC: {state.pc}")
    if MEM_WB.last:break
    writeBack(state, MEM_WB)
    memory(state, EX_MEM, MEM_WB)
    ldHazard = hazard_unit(ID_EX, state, EX_MEM, MEM_WB, IF_ID)
    if ldHazard:
        state.pc = IF_ID.thisPC
        state.idexFlush = 1
        print("load hazard detected")
    else:
        state.ifidFlush = 0
        state.idexFlush = 0
    execute(state, ID_EX, EX_MEM)
    decode(state, IF_ID, ID_EX)
    fetch(state, instructions, IF_ID)
    
    #pipeline register states
    printState(stages)
    cycle +=1
state.pc = 0


def print_registers(registers):
    print("\nFinal Register Values:")
    print(f"{'-' * 50}")
    for i, value in enumerate(registers):
        print(f"R{i:2}: {value}")
    print(f"{'-' * 50}\n")

print_registers(state.registers[0:32])

def printMemory(memory):
    print ("\nFinal mem values:")
    print(f"{"-"*50}")
    for i in range(15):
        print(f"M{i:2}: {memory[i]}")
    print(f"{"-"*50}")
printMemory(state.memory)
# Out:
# --------------------------------------------------
# Cycle 0
# --------------------------------------------------
# PC: 0
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A404D0>
# instructionVal: 0b110100000000100000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 2
# thisPC: 0
# pcp1: 1
# nextpc: 1
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 0
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 0
# pcp1: 0
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: 0
# instructionVal: 0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 0
# pc: 0
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: 0
# instructionVal: 0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 0
# pc: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 1
# --------------------------------------------------
# PC: 1
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b111000000010100000000000000000
# prediction: 0
# stateIndex: 1
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 10
# thisPC: 1
# pcp1: 2
# nextpc: 2
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A404D0>
# instructionVal: 0b110100000000100000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 2
# rd: 0
# thisPC: 0
# pcp1: 1
# destreg: 2
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: 0
# instructionVal: 0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 0
# pc: 0
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: 0
# instructionVal: 0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 0
# pc: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 2
# --------------------------------------------------
# PC: 2
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000000101000000000000001010
# prediction: 0
# stateIndex: 2
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 20
# thisPC: 2
# pcp1: 3
# nextpc: 3
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b111000000010100000000000000000
# prediction: 0
# stateIndex: 1
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 10
# rd: 0
# thisPC: 1
# pcp1: 2
# destreg: 10
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A404D0>
# instructionVal: 0b110100000000100000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 2
# rd: 0
# op1: 0
# op2: 0
# thisPC: 0
# destreg: 2
# pcp1: 1
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: 0
# instructionVal: 0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 0
# pc: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 3
# --------------------------------------------------
# PC: 3
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2690>
# instructionVal: 0b10100000100000
# prediction: 0
# stateIndex: 3
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# thisPC: 3
# pcp1: 4
# nextpc: 4
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000000101000000000000001010
# prediction: 0
# stateIndex: 2
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 10
# rs: 0
# rt: 20
# rd: 0
# thisPC: 2
# pcp1: 3
# destreg: 20
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b111000000010100000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 10
# rd: 0
# op1: 0
# op2: 0
# thisPC: 1
# destreg: 10
# pcp1: 2
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A404D0>
# instructionVal: 0b110100000000100000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 2
# rd: 0
# thisPC: 0
# destreg: 2
# --------------------
#
#
# --------------------------------------------------
# Cycle 4
# --------------------------------------------------
# PC: 4
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A404D0>
# instructionVal: 0b100000000000010000000000000001
# prediction: 0
# stateIndex: 4
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 1
# thisPC: 4
# pcp1: 5
# nextpc: 5
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2690>
# instructionVal: 0b10100000100000
# prediction: 0
# stateIndex: 3
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 5
# thisPC: 3
# pcp1: 4
# destreg: 5
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000000101000000000000001010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 10
# done: 1
# pc: 0
# forwardBres: 0
# imm: 10
# readData1: 0
# taken: 0
# rs: 0
# rt: 20
# rd: 0
# op1: 0
# op2: 10
# thisPC: 2
# destreg: 20
# pcp1: 3
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b111000000010100000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 10
# rd: 0
# thisPC: 1
# destreg: 10
# --------------------
#
#
# --------------------------------------------------
# Cycle 5
# --------------------------------------------------
# PC: 5
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b100000000101101111111111111111
# prediction: 0
# stateIndex: 5
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 22
# thisPC: 5
# pcp1: 6
# nextpc: 6
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A404D0>
# instructionVal: 0b100000000000010000000000000001
# prediction: 0
# stateIndex: 4
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 1
# rs: 0
# rt: 1
# rd: 0
# thisPC: 4
# pcp1: 5
# destreg: 1
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2690>
# instructionVal: 0b10100000100000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 0
# rd: 5
# op1: 0
# op2: 0
# thisPC: 3
# destreg: 5
# pcp1: 4
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000000101000000000000001010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 10
# done: 1
# pc: 0
# rs: 0
# rt: 20
# rd: 0
# thisPC: 2
# destreg: 20
# --------------------
#
#
# --------------------------------------------------
# Cycle 6
# --------------------------------------------------
# PC: 6
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b1000000010100000100000
# prediction: 0
# stateIndex: 6
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 1
# rt: 0
# thisPC: 6
# pcp1: 7
# nextpc: 7
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b100000000101101111111111111111
# prediction: 0
# stateIndex: 5
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: -1
# rs: 0
# rt: 22
# rd: 31
# thisPC: 5
# pcp1: 6
# destreg: 22
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A404D0>
# instructionVal: 0b100000000000010000000000000001
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# forwardBres: 0
# imm: 1
# readData1: 0
# taken: 0
# rs: 0
# rt: 1
# rd: 0
# op1: 0
# op2: 1
# thisPC: 4
# destreg: 1
# pcp1: 5
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2690>
# instructionVal: 0b10100000100000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# rd: 5
# thisPC: 3
# destreg: 5
# --------------------
#
#
# --------------------------------------------------
# Cycle 7
# --------------------------------------------------
# PC: 7
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2690>
# instructionVal: 0b10001100101011110000000000000000
# prediction: 0
# stateIndex: 7
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 5
# rt: 15
# thisPC: 7
# pcp1: 8
# nextpc: 8
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b1000000010100000100000
# prediction: 0
# stateIndex: 6
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 1
# rt: 0
# rd: 5
# thisPC: 6
# pcp1: 7
# destreg: 5
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b100000000101101111111111111111
# prediction: 0
# stateIndex: 0
# last: 0
# data: -1
# done: 1
# pc: 0
# forwardBres: 0
# imm: -1
# readData1: 0
# taken: 0
# rs: 0
# rt: 22
# rd: 31
# op1: 0
# op2: -1
# thisPC: 5
# destreg: 22
# pcp1: 6
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A404D0>
# instructionVal: 0b100000000000010000000000000001
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# rs: 0
# rt: 1
# rd: 0
# thisPC: 4
# destreg: 1
# --------------------
#
#
# --------------------------------------------------
# Cycle 8
# --------------------------------------------------
# PC: 8
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A404D0>
# instructionVal: 0b1111000000101000000100101
# prediction: 0
# stateIndex: 8
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 15
# rt: 0
# thisPC: 8
# pcp1: 9
# nextpc: 9
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2690>
# instructionVal: 0b10001100101011110000000000000000
# prediction: 0
# stateIndex: 7
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 5
# rt: 15
# rd: 0
# thisPC: 7
# pcp1: 8
# destreg: 15
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b1000000010100000100000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 1
# rt: 0
# rd: 5
# op1: 1
# op2: 0
# thisPC: 6
# destreg: 5
# pcp1: 7
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b100000000101101111111111111111
# prediction: 0
# stateIndex: 0
# last: 0
# data: -1
# done: 1
# pc: 0
# rs: 0
# rt: 22
# rd: 31
# thisPC: 5
# destreg: 22
# --------------------
#
#
# --------------------------------------------------
# Cycle 9
# --------------------------------------------------
# PC: 9
# load hazard detected
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF0B90>
# instructionVal: 0b1111000000101000000100101
# prediction: 0
# stateIndex: 8
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 15
# rt: 0
# thisPC: 8
# pcp1: 9
# nextpc: 9
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 8
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 8
# pcp1: 9
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2690>
# instructionVal: 0b10001100101011110000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 5
# rt: 15
# rd: 0
# op1: 1
# op2: 0
# thisPC: 7
# destreg: 15
# pcp1: 8
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b1000000010100000100000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# rs: 1
# rt: 0
# rd: 5
# thisPC: 6
# destreg: 5
# --------------------
#
#
# --------------------------------------------------
# Cycle 10
# --------------------------------------------------
# PC: 9
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b100000001000101111111111111111
# prediction: 0
# stateIndex: 9
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 1
# rt: 2
# thisPC: 9
# pcp1: 10
# nextpc: 10
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF0B90>
# instructionVal: 0b1111000000101000000100101
# prediction: 0
# stateIndex: 8
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 15
# rt: 0
# rd: 10
# thisPC: 8
# pcp1: 9
# destreg: 10
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# thisPC: 8
# destreg: 0
# pcp1: 9
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2690>
# instructionVal: 0b10001100101011110000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 7
# done: 1
# pc: 0
# rs: 5
# rt: 15
# rd: 0
# thisPC: 7
# destreg: 15
# --------------------
#
#
# --------------------------------------------------
# Cycle 11
# --------------------------------------------------
# PC: 10
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b10000000011000000100000
# prediction: 0
# stateIndex: 10
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 2
# rt: 0
# thisPC: 10
# pcp1: 11
# nextpc: 11
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b100000001000101111111111111111
# prediction: 0
# stateIndex: 9
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 1
# readData2: 0
# imm: -1
# rs: 1
# rt: 2
# rd: 31
# thisPC: 9
# pcp1: 10
# destreg: 2
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF0B90>
# instructionVal: 0b1111000000101000000100101
# prediction: 0
# stateIndex: 0
# last: 0
# data: 7
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 15
# rt: 0
# rd: 10
# op1: 7
# op2: 0
# thisPC: 8
# destreg: 10
# pcp1: 9
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 8
# destreg: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 12
# --------------------------------------------------
# PC: 11
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10001100110100000000000000000000
# prediction: 0
# stateIndex: 11
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 6
# rt: 16
# thisPC: 11
# pcp1: 12
# nextpc: 12
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b10000000011000000100000
# prediction: 0
# stateIndex: 10
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 2
# rt: 0
# rd: 6
# thisPC: 10
# pcp1: 11
# destreg: 6
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b100000001000101111111111111111
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: -1
# readData1: 1
# taken: 0
# rs: 1
# rt: 2
# rd: 31
# op1: 1
# op2: -1
# thisPC: 9
# destreg: 2
# pcp1: 10
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF0B90>
# instructionVal: 0b1111000000101000000100101
# prediction: 0
# stateIndex: 0
# last: 0
# data: 7
# done: 1
# pc: 0
# rs: 15
# rt: 0
# rd: 10
# thisPC: 8
# destreg: 10
# --------------------
#
#
# --------------------------------------------------
# Cycle 13
# --------------------------------------------------
# PC: 12
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF0B90>
# instructionVal: 0b10110000101100100000101010
# prediction: 0
# stateIndex: 12
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 22
# rt: 2
# thisPC: 12
# pcp1: 13
# nextpc: 13
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10001100110100000000000000000000
# prediction: 0
# stateIndex: 11
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 6
# rt: 16
# rd: 0
# thisPC: 11
# pcp1: 12
# destreg: 16
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b10000000011000000100000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 2
# rt: 0
# rd: 6
# op1: 0
# op2: 0
# thisPC: 10
# destreg: 6
# pcp1: 11
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b100000001000101111111111111111
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 1
# rt: 2
# rd: 31
# thisPC: 9
# destreg: 2
# --------------------
#
#
# --------------------------------------------------
# Cycle 14
# --------------------------------------------------
# PC: 13
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b1010100001101000000101010
# prediction: 0
# stateIndex: 13
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 10
# rt: 16
# thisPC: 13
# pcp1: 14
# nextpc: 14
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF0B90>
# instructionVal: 0b10110000101100100000101010
# prediction: 0
# stateIndex: 12
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: -1
# readData2: 0
# imm: 0
# rs: 22
# rt: 2
# rd: 25
# thisPC: 12
# pcp1: 13
# destreg: 25
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10001100110100000000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 6
# rt: 16
# rd: 0
# op1: 0
# op2: 0
# thisPC: 11
# destreg: 16
# pcp1: 12
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b10000000011000000100000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 2
# rt: 0
# rd: 6
# thisPC: 10
# destreg: 6
# --------------------
#
#
# --------------------------------------------------
# Cycle 15
# --------------------------------------------------
# PC: 14
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b11010110011101100000100100
# prediction: 0
# stateIndex: 14
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 26
# rt: 25
# thisPC: 14
# pcp1: 15
# nextpc: 15
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b1010100001101000000101010
# prediction: 0
# stateIndex: 13
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 7
# readData2: 0
# imm: 0
# rs: 10
# rt: 16
# rd: 26
# thisPC: 13
# pcp1: 14
# destreg: 26
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF0B90>
# instructionVal: 0b10110000101100100000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: -1
# taken: 0
# rs: 22
# rt: 2
# rd: 25
# op1: -1
# op2: 0
# thisPC: 12
# destreg: 25
# pcp1: 13
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10001100110100000000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 5
# done: 1
# pc: 0
# rs: 6
# rt: 16
# rd: 0
# thisPC: 11
# destreg: 16
# --------------------
#
#
# --------------------------------------------------
# Cycle 16
# --------------------------------------------------
# PC: 15
#
#  NOT TAKEN
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10000000110110000000000000100
# prediction: 0
# stateIndex: 15
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 27
# thisPC: 15
# pcp1: 16
# nextpc: 16
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b11010110011101100000100100
# prediction: 0
# stateIndex: 14
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 26
# rt: 25
# rd: 27
# thisPC: 14
# pcp1: 15
# destreg: 27
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b1010100001101000000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 7
# taken: 0
# rs: 10
# rt: 16
# rd: 26
# op1: 7
# op2: 5
# thisPC: 13
# destreg: 26
# pcp1: 14
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF0B90>
# instructionVal: 0b10110000101100100000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# rs: 22
# rt: 2
# rd: 25
# thisPC: 12
# destreg: 25
# --------------------
#
#
# --------------------------------------------------
# Cycle 17
# --------------------------------------------------
# PC: 16
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF0B90>
# instructionVal: 0b100000010001110000000000000001
# prediction: 0
# stateIndex: 16
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 2
# rt: 7
# thisPC: 16
# pcp1: 17
# nextpc: 17
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10000000110110000000000000100
# prediction: 0
# stateIndex: 15
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 4
# rs: 0
# rt: 27
# rd: 0
# thisPC: 15
# pcp1: 16
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b11010110011101100000100100
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 26
# rt: 25
# rd: 27
# op1: 0
# op2: 1
# thisPC: 14
# destreg: 27
# pcp1: 15
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b1010100001101000000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 10
# rt: 16
# rd: 26
# thisPC: 13
# destreg: 26
# --------------------
#
#
# --------------------------------------------------
# Cycle 18
# --------------------------------------------------
# PC: 17
# flush detected
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2510>
# instructionVal: 0
# prediction: 0
# stateIndex: 16
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# thisPC: 16
# pcp1: 17
# nextpc: 20
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 16
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 16
# pcp1: 17
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10000000110110000000000000100
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 4
# readData1: 0
# taken: 1
# rs: 0
# rt: 27
# rd: 0
# op1: 0
# op2: 0
# thisPC: 15
# destreg: 0
# pcp1: 16
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b11010110011101100000100100
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 26
# rt: 25
# rd: 27
# thisPC: 14
# destreg: 27
# --------------------
#
#
# --------------------------------------------------
# Cycle 19
# --------------------------------------------------
# PC: 20
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b100000010001110000000000000001
# prediction: 0
# stateIndex: 21
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 2
# rt: 7
# thisPC: 20
# pcp1: 21
# nextpc: 21
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2510>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 16
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 16
# pcp1: 17
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# thisPC: 16
# destreg: 0
# pcp1: 17
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10000000110110000000000000100
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 27
# rd: 0
# thisPC: 15
# destreg: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 20
# --------------------------------------------------
# PC: 21
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10101100111010100000000000000000
# prediction: 0
# stateIndex: 20
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 7
# rt: 10
# thisPC: 21
# pcp1: 22
# nextpc: 22
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b100000010001110000000000000001
# prediction: 0
# stateIndex: 21
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 1
# rs: 2
# rt: 7
# rd: 0
# thisPC: 20
# pcp1: 21
# destreg: 7
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2510>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# thisPC: 16
# destreg: 0
# pcp1: 17
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 16
# destreg: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 21
# --------------------------------------------------
# PC: 22
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000001000010000000000000001
# prediction: 0
# stateIndex: 23
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 1
# rt: 1
# thisPC: 22
# pcp1: 23
# nextpc: 23
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10101100111010100000000000000000
# prediction: 0
# stateIndex: 20
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 7
# rt: 10
# rd: 0
# thisPC: 21
# pcp1: 22
# destreg: 10
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b100000010001110000000000000001
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# forwardBres: 0
# imm: 1
# readData1: 0
# taken: 0
# rs: 2
# rt: 7
# rd: 0
# op1: 0
# op2: 1
# thisPC: 20
# destreg: 7
# pcp1: 21
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2510>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 16
# destreg: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 22
# --------------------------------------------------
# PC: 23
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2810>
# instructionVal: 0b1101001110000000101010
# prediction: 0
# stateIndex: 22
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 1
# rt: 20
# thisPC: 23
# pcp1: 24
# nextpc: 24
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000001000010000000000000001
# prediction: 0
# stateIndex: 23
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 1
# readData2: 0
# imm: 1
# rs: 1
# rt: 1
# rd: 0
# thisPC: 22
# pcp1: 23
# destreg: 1
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10101100111010100000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 7
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 7
# rt: 10
# rd: 0
# op1: 1
# op2: 0
# thisPC: 21
# destreg: 10
# pcp1: 22
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b100000010001110000000000000001
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# rs: 2
# rt: 7
# rd: 0
# thisPC: 20
# destreg: 7
# --------------------
#
#
# --------------------------------------------------
# Cycle 23
# --------------------------------------------------
# PC: 24
#
#  NOT TAKEN
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b10100000111001111111111101101
# prediction: 0
# stateIndex: 25
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 28
# thisPC: 24
# pcp1: 25
# nextpc: 25
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2810>
# instructionVal: 0b1101001110000000101010
# prediction: 0
# stateIndex: 22
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 1
# readData2: 10
# imm: 0
# rs: 1
# rt: 20
# rd: 28
# thisPC: 23
# pcp1: 24
# destreg: 28
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000001000010000000000000001
# prediction: 0
# stateIndex: 0
# last: 0
# data: 2
# done: 1
# pc: 0
# forwardBres: 0
# imm: 1
# readData1: 1
# taken: 0
# rs: 1
# rt: 1
# rd: 0
# op1: 1
# op2: 1
# thisPC: 22
# destreg: 1
# pcp1: 23
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10101100111010100000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 7
# done: 1
# pc: 0
# rs: 7
# rt: 10
# rd: 0
# thisPC: 21
# destreg: 10
# --------------------
#
#
# --------------------------------------------------
# Cycle 24
# --------------------------------------------------
# PC: 25
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 24
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# thisPC: 25
# pcp1: 26
# nextpc: 26
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b10100000111001111111111101101
# prediction: 0
# stateIndex: 25
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: -19
# rs: 0
# rt: 28
# rd: 31
# thisPC: 24
# pcp1: 25
# destreg: 31
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2810>
# instructionVal: 0b1101001110000000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 1
# taken: 0
# rs: 1
# rt: 20
# rd: 28
# op1: 2
# op2: 10
# thisPC: 23
# destreg: 28
# pcp1: 24
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000001000010000000000000001
# prediction: 0
# stateIndex: 0
# last: 0
# data: 2
# done: 1
# pc: 0
# rs: 1
# rt: 1
# rd: 0
# thisPC: 22
# destreg: 1
# --------------------
#
#
# --------------------------------------------------
# Cycle 25
# --------------------------------------------------
# PC: 26
# flush detected
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF0350>
# instructionVal: 0
# prediction: 0
# stateIndex: 24
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# thisPC: 25
# pcp1: 26
# nextpc: 6
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 24
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 25
# pcp1: 26
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b10100000111001111111111101101
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: -19
# readData1: 0
# taken: 1
# rs: 0
# rt: 28
# rd: 31
# op1: 0
# op2: 1
# thisPC: 24
# destreg: 31
# pcp1: 25
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF2810>
# instructionVal: 0b1101001110000000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# rs: 1
# rt: 20
# rd: 28
# thisPC: 23
# destreg: 28
# --------------------
#
#
# --------------------------------------------------
# Cycle 26
# --------------------------------------------------
# PC: 6
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b1000000010100000100000
# prediction: 0
# stateIndex: 5
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 1
# rt: 0
# thisPC: 6
# pcp1: 7
# nextpc: 7
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF0350>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 24
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 25
# pcp1: 26
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# thisPC: 25
# destreg: 0
# pcp1: 26
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b10100000111001111111111101101
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 28
# rd: 31
# thisPC: 24
# destreg: 31
# --------------------
#
#
# --------------------------------------------------
# Cycle 27
# --------------------------------------------------
# PC: 7
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b10001100101011110000000000000000
# prediction: 0
# stateIndex: 4
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 5
# rt: 15
# thisPC: 7
# pcp1: 8
# nextpc: 8
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b1000000010100000100000
# prediction: 0
# stateIndex: 5
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 2
# readData2: 0
# imm: 0
# rs: 1
# rt: 0
# rd: 5
# thisPC: 6
# pcp1: 7
# destreg: 5
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF0350>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# thisPC: 25
# destreg: 0
# pcp1: 26
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 25
# destreg: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 28
# --------------------------------------------------
# PC: 8
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b1111000000101000000100101
# prediction: 0
# stateIndex: 11
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 15
# rt: 0
# thisPC: 8
# pcp1: 9
# nextpc: 9
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b10001100101011110000000000000000
# prediction: 0
# stateIndex: 4
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 1
# readData2: 0
# imm: 0
# rs: 5
# rt: 15
# rd: 0
# thisPC: 7
# pcp1: 8
# destreg: 15
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b1000000010100000100000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 2
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 2
# taken: 0
# rs: 1
# rt: 0
# rd: 5
# op1: 2
# op2: 0
# thisPC: 6
# destreg: 5
# pcp1: 7
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF0350>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 25
# destreg: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 29
# --------------------------------------------------
# PC: 9
# load hazard detected
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF13A0>
# instructionVal: 0b1111000000101000000100101
# prediction: 0
# stateIndex: 11
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 15
# rt: 0
# thisPC: 8
# pcp1: 9
# nextpc: 9
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 11
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 8
# pcp1: 9
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b10001100101011110000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 1
# taken: 0
# rs: 5
# rt: 15
# rd: 0
# op1: 2
# op2: 0
# thisPC: 7
# destreg: 15
# pcp1: 8
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b1000000010100000100000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 2
# done: 1
# pc: 0
# rs: 1
# rt: 0
# rd: 5
# thisPC: 6
# destreg: 5
# --------------------
#
#
# --------------------------------------------------
# Cycle 30
# --------------------------------------------------
# PC: 9
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b100000001000101111111111111111
# prediction: 0
# stateIndex: 10
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 1
# rt: 2
# thisPC: 9
# pcp1: 10
# nextpc: 10
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF13A0>
# instructionVal: 0b1111000000101000000100101
# prediction: 0
# stateIndex: 11
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 7
# readData2: 0
# imm: 0
# rs: 15
# rt: 0
# rd: 10
# thisPC: 8
# pcp1: 9
# destreg: 10
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# thisPC: 8
# destreg: 0
# pcp1: 9
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b10001100101011110000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 2
# done: 1
# pc: 0
# rs: 5
# rt: 15
# rd: 0
# thisPC: 7
# destreg: 15
# --------------------
#
#
# --------------------------------------------------
# Cycle 31
# --------------------------------------------------
# PC: 10
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b10000000011000000100000
# prediction: 0
# stateIndex: 9
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 2
# rt: 0
# thisPC: 10
# pcp1: 11
# nextpc: 11
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b100000001000101111111111111111
# prediction: 0
# stateIndex: 10
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 2
# readData2: 0
# imm: -1
# rs: 1
# rt: 2
# rd: 31
# thisPC: 9
# pcp1: 10
# destreg: 2
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF13A0>
# instructionVal: 0b1111000000101000000100101
# prediction: 0
# stateIndex: 0
# last: 0
# data: 2
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 7
# taken: 0
# rs: 15
# rt: 0
# rd: 10
# op1: 2
# op2: 0
# thisPC: 8
# destreg: 10
# pcp1: 9
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 8
# destreg: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 32
# --------------------------------------------------
# PC: 11
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10001100110100000000000000000000
# prediction: 0
# stateIndex: 8
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 6
# rt: 16
# thisPC: 11
# pcp1: 12
# nextpc: 12
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b10000000011000000100000
# prediction: 0
# stateIndex: 9
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 2
# rt: 0
# rd: 6
# thisPC: 10
# pcp1: 11
# destreg: 6
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b100000001000101111111111111111
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# forwardBres: 0
# imm: -1
# readData1: 2
# taken: 0
# rs: 1
# rt: 2
# rd: 31
# op1: 2
# op2: -1
# thisPC: 9
# destreg: 2
# pcp1: 10
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF13A0>
# instructionVal: 0b1111000000101000000100101
# prediction: 0
# stateIndex: 0
# last: 0
# data: 2
# done: 1
# pc: 0
# rs: 15
# rt: 0
# rd: 10
# thisPC: 8
# destreg: 10
# --------------------
#
#
# --------------------------------------------------
# Cycle 33
# --------------------------------------------------
# PC: 12
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b10110000101100100000101010
# prediction: 0
# stateIndex: 15
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 22
# rt: 2
# thisPC: 12
# pcp1: 13
# nextpc: 13
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10001100110100000000000000000000
# prediction: 0
# stateIndex: 8
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 6
# rt: 16
# rd: 0
# thisPC: 11
# pcp1: 12
# destreg: 16
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b10000000011000000100000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 2
# rt: 0
# rd: 6
# op1: 1
# op2: 0
# thisPC: 10
# destreg: 6
# pcp1: 11
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b100000001000101111111111111111
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# rs: 1
# rt: 2
# rd: 31
# thisPC: 9
# destreg: 2
# --------------------
#
#
# --------------------------------------------------
# Cycle 34
# --------------------------------------------------
# PC: 13
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b1010100001101000000101010
# prediction: 0
# stateIndex: 14
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 10
# rt: 16
# thisPC: 13
# pcp1: 14
# nextpc: 14
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b10110000101100100000101010
# prediction: 0
# stateIndex: 15
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: -1
# readData2: 1
# imm: 0
# rs: 22
# rt: 2
# rd: 25
# thisPC: 12
# pcp1: 13
# destreg: 25
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10001100110100000000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 6
# rt: 16
# rd: 0
# op1: 1
# op2: 0
# thisPC: 11
# destreg: 16
# pcp1: 12
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b10000000011000000100000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# rs: 2
# rt: 0
# rd: 6
# thisPC: 10
# destreg: 6
# --------------------
#
#
# --------------------------------------------------
# Cycle 35
# --------------------------------------------------
# PC: 14
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b11010110011101100000100100
# prediction: 0
# stateIndex: 13
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 26
# rt: 25
# thisPC: 14
# pcp1: 15
# nextpc: 15
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b1010100001101000000101010
# prediction: 0
# stateIndex: 14
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 2
# readData2: 5
# imm: 0
# rs: 10
# rt: 16
# rd: 26
# thisPC: 13
# pcp1: 14
# destreg: 26
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b10110000101100100000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: -1
# taken: 0
# rs: 22
# rt: 2
# rd: 25
# op1: -1
# op2: 1
# thisPC: 12
# destreg: 25
# pcp1: 13
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10001100110100000000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 7
# done: 1
# pc: 0
# rs: 6
# rt: 16
# rd: 0
# thisPC: 11
# destreg: 16
# --------------------
#
#
# --------------------------------------------------
# Cycle 36
# --------------------------------------------------
# PC: 15
#
#  NOT TAKEN
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10000000110110000000000000100
# prediction: 0
# stateIndex: 12
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 27
# thisPC: 15
# pcp1: 16
# nextpc: 16
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b11010110011101100000100100
# prediction: 0
# stateIndex: 13
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 1
# imm: 0
# rs: 26
# rt: 25
# rd: 27
# thisPC: 14
# pcp1: 15
# destreg: 27
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b1010100001101000000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 2
# taken: 0
# rs: 10
# rt: 16
# rd: 26
# op1: 2
# op2: 7
# thisPC: 13
# destreg: 26
# pcp1: 14
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b10110000101100100000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# rs: 22
# rt: 2
# rd: 25
# thisPC: 12
# destreg: 25
# --------------------
#
#
# --------------------------------------------------
# Cycle 37
# --------------------------------------------------
# PC: 16
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000010001110000000000000001
# prediction: 0
# stateIndex: 19
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 2
# rt: 7
# thisPC: 16
# pcp1: 17
# nextpc: 17
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10000000110110000000000000100
# prediction: 0
# stateIndex: 12
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 4
# rs: 0
# rt: 27
# rd: 0
# thisPC: 15
# pcp1: 16
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b11010110011101100000100100
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 26
# rt: 25
# rd: 27
# op1: 1
# op2: 1
# thisPC: 14
# destreg: 27
# pcp1: 15
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b1010100001101000000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# rs: 10
# rt: 16
# rd: 26
# thisPC: 13
# destreg: 26
# --------------------
#
#
# --------------------------------------------------
# Cycle 38
# --------------------------------------------------
# PC: 17
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10101100111100000000000000000000
# prediction: 0
# stateIndex: 23
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 7
# rt: 16
# thisPC: 17
# pcp1: 18
# nextpc: 18
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000010001110000000000000001
# prediction: 0
# stateIndex: 19
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 1
# readData2: 0
# imm: 1
# rs: 2
# rt: 7
# rd: 0
# thisPC: 16
# pcp1: 17
# destreg: 7
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10000000110110000000000000100
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 4
# readData1: 0
# taken: 0
# rs: 0
# rt: 27
# rd: 0
# op1: 0
# op2: 1
# thisPC: 15
# destreg: 0
# pcp1: 16
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b11010110011101100000100100
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# rs: 26
# rt: 25
# rd: 27
# thisPC: 14
# destreg: 27
# --------------------
#
#
# --------------------------------------------------
# Cycle 39
# --------------------------------------------------
# PC: 18
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b100000010000101111111111111111
# prediction: 0
# stateIndex: 20
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 2
# rt: 2
# thisPC: 18
# pcp1: 19
# nextpc: 19
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b10101100111100000000000000000000
# prediction: 0
# stateIndex: 23
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 1
# readData2: 0
# imm: 0
# rs: 7
# rt: 16
# rd: 0
# thisPC: 17
# pcp1: 18
# destreg: 16
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000010001110000000000000001
# prediction: 0
# stateIndex: 0
# last: 0
# data: 2
# done: 1
# pc: 0
# forwardBres: 0
# imm: 1
# readData1: 1
# taken: 0
# rs: 2
# rt: 7
# rd: 0
# op1: 1
# op2: 1
# thisPC: 16
# destreg: 7
# pcp1: 17
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10000000110110000000000000100
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 27
# rd: 0
# thisPC: 15
# ...
# stateIndex: 17
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 27
# thisPC: 15
# pcp1: 16
# nextpc: 16
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b11010110011101100000100100
# prediction: 0
# stateIndex: 16
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 1
# readData2: 1
# imm: 0
# rs: 26
# rt: 25
# rd: 27
# thisPC: 14
# pcp1: 15
# destreg: 27
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b1010100001101000000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 85
# taken: 0
# rs: 10
# rt: 16
# rd: 26
# op1: 85
# op2: 48
# thisPC: 13
# destreg: 26
# pcp1: 14
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b10110000101100100000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 1
# done: 1
# pc: 0
# rs: 22
# rt: 2
# rd: 25
# thisPC: 12
# destreg: 25
# --------------------
#
#
# --------------------------------------------------
# Cycle 287
# --------------------------------------------------
# PC: 16
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A19700>
# instructionVal: 0b100000010001110000000000000001
# prediction: 0
# stateIndex: 14
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 2
# rt: 7
# thisPC: 16
# pcp1: 17
# nextpc: 17
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10000000110110000000000000100
# prediction: 0
# stateIndex: 17
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 4
# rs: 0
# rt: 27
# rd: 0
# thisPC: 15
# pcp1: 16
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b11010110011101100000100100
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 1
# taken: 0
# rs: 26
# rt: 25
# rd: 27
# op1: 0
# op2: 1
# thisPC: 14
# destreg: 27
# pcp1: 15
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b1010100001101000000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 10
# rt: 16
# rd: 26
# thisPC: 13
# destreg: 26
# --------------------
#
#
# --------------------------------------------------
# Cycle 288
# --------------------------------------------------
# PC: 17
# flush detected
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF13A0>
# instructionVal: 0
# prediction: 0
# stateIndex: 14
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# thisPC: 16
# pcp1: 17
# nextpc: 20
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 14
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 16
# pcp1: 17
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10000000110110000000000000100
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 4
# readData1: 0
# taken: 1
# rs: 0
# rt: 27
# rd: 0
# op1: 0
# op2: 0
# thisPC: 15
# destreg: 0
# pcp1: 16
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b11010110011101100000100100
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 26
# rt: 25
# rd: 27
# thisPC: 14
# destreg: 27
# --------------------
#
#
# --------------------------------------------------
# Cycle 289
# --------------------------------------------------
# PC: 20
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b100000010001110000000000000001
# prediction: 0
# stateIndex: 9
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 2
# rt: 7
# thisPC: 20
# pcp1: 21
# nextpc: 21
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF13A0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 14
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 16
# pcp1: 17
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# thisPC: 16
# destreg: 0
# pcp1: 17
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10000000110110000000000000100
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 27
# rd: 0
# thisPC: 15
# destreg: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 290
# --------------------------------------------------
# PC: 21
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10101100111010100000000000000000
# prediction: 0
# stateIndex: 8
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 7
# rt: 10
# thisPC: 21
# pcp1: 22
# nextpc: 22
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b100000010001110000000000000001
# prediction: 0
# stateIndex: 9
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 7
# readData2: 0
# imm: 1
# rs: 2
# rt: 7
# rd: 0
# thisPC: 20
# pcp1: 21
# destreg: 7
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF13A0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# thisPC: 16
# destreg: 0
# pcp1: 17
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215B43BF0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 16
# destreg: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 291
# --------------------------------------------------
# PC: 22
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000001000010000000000000001
# prediction: 0
# stateIndex: 11
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 1
# rt: 1
# thisPC: 22
# pcp1: 23
# nextpc: 23
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10101100111010100000000000000000
# prediction: 0
# stateIndex: 8
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 9
# readData2: 0
# imm: 0
# rs: 7
# rt: 10
# rd: 0
# thisPC: 21
# pcp1: 22
# destreg: 10
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b100000010001110000000000000001
# prediction: 0
# stateIndex: 0
# last: 0
# data: 8
# done: 1
# pc: 0
# forwardBres: 0
# imm: 1
# readData1: 7
# taken: 0
# rs: 2
# rt: 7
# rd: 0
# op1: 7
# op2: 1
# thisPC: 20
# destreg: 7
# pcp1: 21
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215BF13A0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 16
# destreg: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 292
# --------------------------------------------------
# PC: 23
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b1101001110000000101010
# prediction: 0
# stateIndex: 10
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 1
# rt: 20
# thisPC: 23
# pcp1: 24
# nextpc: 24
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000001000010000000000000001
# prediction: 0
# stateIndex: 11
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 9
# readData2: 0
# imm: 1
# rs: 1
# rt: 1
# rd: 0
# thisPC: 22
# pcp1: 23
# destreg: 1
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10101100111010100000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 85
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 9
# taken: 0
# rs: 7
# rt: 10
# rd: 0
# op1: 8
# op2: 0
# thisPC: 21
# destreg: 10
# pcp1: 22
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b100000010001110000000000000001
# prediction: 0
# stateIndex: 0
# last: 0
# data: 8
# done: 1
# pc: 0
# rs: 2
# rt: 7
# rd: 0
# thisPC: 20
# destreg: 7
# --------------------
#
#
# --------------------------------------------------
# Cycle 293
# --------------------------------------------------
# PC: 24
#
#  NOT TAKEN
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b10100000111001111111111101101
# prediction: 0
# stateIndex: 5
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 28
# thisPC: 24
# pcp1: 25
# nextpc: 25
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b1101001110000000101010
# prediction: 0
# stateIndex: 10
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 9
# readData2: 10
# imm: 0
# rs: 1
# rt: 20
# rd: 28
# thisPC: 23
# pcp1: 24
# destreg: 28
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000001000010000000000000001
# prediction: 0
# stateIndex: 0
# last: 0
# data: 10
# done: 1
# pc: 0
# forwardBres: 0
# imm: 1
# readData1: 9
# taken: 0
# rs: 1
# rt: 1
# rd: 0
# op1: 9
# op2: 1
# thisPC: 22
# destreg: 1
# pcp1: 23
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b10101100111010100000000000000000
# prediction: 0
# stateIndex: 0
# last: 0
# data: 85
# done: 1
# pc: 0
# rs: 7
# rt: 10
# rd: 0
# thisPC: 21
# destreg: 10
# --------------------
#
#
# --------------------------------------------------
# Cycle 294
# --------------------------------------------------
# PC: 25
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 4
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# thisPC: 25
# pcp1: 26
# nextpc: 26
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b10100000111001111111111101101
# prediction: 0
# stateIndex: 5
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: -19
# rs: 0
# rt: 28
# rd: 31
# thisPC: 24
# pcp1: 25
# destreg: 31
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b1101001110000000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 9
# taken: 0
# rs: 1
# rt: 20
# rd: 28
# op1: 10
# op2: 10
# thisPC: 23
# destreg: 28
# pcp1: 24
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b100000001000010000000000000001
# prediction: 0
# stateIndex: 0
# last: 0
# data: 10
# done: 1
# pc: 0
# rs: 1
# rt: 1
# rd: 0
# thisPC: 22
# destreg: 1
# --------------------
#
#
# --------------------------------------------------
# Cycle 295
# --------------------------------------------------
# PC: 26
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 1
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# thisPC: 26
# pcp1: 27
# nextpc: 27
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 4
# last: 0
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 25
# pcp1: 26
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b10100000111001111111111101101
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: -19
# readData1: 0
# taken: 0
# rs: 0
# rt: 28
# rd: 31
# op1: 0
# op2: 0
# thisPC: 24
# destreg: 31
# pcp1: 25
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b1101001110000000101010
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 1
# rt: 20
# rd: 28
# thisPC: 23
# destreg: 28
# --------------------
#
#
# --------------------------------------------------
# Cycle 296
# --------------------------------------------------
# PC: 27
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 1
# last: 1
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# thisPC: 27
# pcp1: 28
# nextpc: 28
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 1
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 26
# pcp1: 27
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# thisPC: 25
# destreg: 0
# pcp1: 26
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b10100000111001111111111101101
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 28
# rd: 31
# thisPC: 24
# destreg: 31
# --------------------
#
#
# --------------------------------------------------
# Cycle 297
# --------------------------------------------------
# PC: 28
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 6
# last: 1
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# thisPC: 28
# pcp1: 29
# nextpc: 29
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 1
# last: 1
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 27
# pcp1: 28
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 1
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# thisPC: 26
# destreg: 0
# pcp1: 27
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215623800>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 25
# destreg: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 298
# --------------------------------------------------
# PC: 29
# IF_ID:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A404D0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 7
# last: 1
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# thisPC: 29
# pcp1: 30
# nextpc: 30
# --------------------
# ID_EX:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A40110>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 6
# last: 1
# data: 0
# done: 1
# pc: 0
# readData1: 0
# readData2: 0
# imm: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 28
# pcp1: 29
# destreg: 0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x00000272143E1AF0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 1
# data: 0
# done: 1
# pc: 0
# forwardBres: 0
# imm: 0
# readData1: 0
# taken: 0
# rs: 0
# rt: 0
# rd: 0
# op1: 0
# op2: 0
# thisPC: 27
# destreg: 0
# pcp1: 28
# --------------------
# MEM_WB:
#
# flush: 0
# instruction: <__main__.Instruction object at 0x0000027215A405C0>
# instructionVal: 0b0
# prediction: 0
# stateIndex: 0
# last: 1
# data: 0
# done: 1
# pc: 0
# rs: 0
# rt: 0
# rd: 0
# thisPC: 26
# destreg: 0
# --------------------
#
#
# --------------------------------------------------
# Cycle 299
# --------------------------------------------------
# PC: 30
#
# Final Register Values:
# --------------------------------------------------
# R 0: 0
# R 1: 10
# R 2: 7
# R 3: 0
# R 4: 0
# R 5: 9
# R 6: 7
# R 7: 8
# R 8: 0
# R 9: 0
# R10: 85
# R11: 0
# R12: 0
# R13: 0
# R14: 0
# R15: 85
# R16: 48
# R17: 0
# R18: 0
# R19: 0
# R20: 10
# R21: 0
# R22: -1
# R23: 0
# R24: 0
# R25: 1
# R26: 0
# R27: 0
# R28: 0
# R29: 0
# R30: 0
# R31: 0
# --------------------------------------------------
#
#
# Final mem values:
# --------------------------------------------------
# M 0: 1
# M 1: 2
# M 2: 5
# M 3: 7
# M 4: 10
# M 5: 15
# M 6: 16
# M 7: 48
# M 8: 85
# M 9: 255
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# --------------------------------------------------
