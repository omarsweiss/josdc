# %%
def runCpu():
    instructions = []
    with open("imem.txt", 'r') as inst:
        for line in inst:
            parts = line.split(":")
            if len(parts)>1:
                instructions.append(int(parts[1].strip().rstrip(";"),2))

    class Instruction:
        def __init__(self, instruction):
            self.instructionVal = bin(instruction)
            self.opcode = instruction >> 26 & 0b111111
            self.rs = instruction >> 21 & 0b11111
            self.rt = instruction >> 16 & 0b11111
            self.rd = instruction >> 11 & 0b11111
            self.shamt = instruction >> 6 & 0b11111
            self.funct = instruction & 0b111111
            self.imm = instruction & 0xFFFF
            self.cycles = [0] * 5 #creates an array for every stage to record at which stage was an instruction in every cycle
                                    #for example, if an instruction was at Decode stage, then self.cycles[0] = 0 and self.cycoles[1] = 1 and so on... a dictionary might be better.


    class PipelineState:
        def __init__(self):
            self.cycle = 0
            self.ifidFlushT = 0
            self.idexFlushT = 0
            self.ifidFlushNT = 0
            self.idexFlushNT = 0
            self.branchflushcount = 0
            self.branchInstruction  = 0
            self.histReg = 0
            self.taken = 1
            self.ifidStall = 0
            self.pcNT = 0
            self.pcT = 0
            self.registers = [0] *32
            self.memory = [0] * 1024 #can be changed to any size depending on the memory size
            
    class PipelineRegister:
        def __init__(self):
            self.flush = 0
            self.instruction1 = 0
            self.instructionVal1 = 0
            self.instruction2 = 0
            self.instructionVal2 = 0
            self.prediction = 0
            self.stateIndex = 0
            self.last = 0
            self.inst2T = Instruction(0)
            self.inst2NT = Instruction(0)
            self.data = 0 # any data, depending on the stage. signals are interpreted directly w/o a CU so no need for multiple signals 
            self.done = 0
            self.flush = 0
            self.pc = 0 

    IF_ID = PipelineRegister()
    ID_EX = PipelineRegister()
    EX_MEM = PipelineRegister()
    MEM_WB = PipelineRegister()
    state = PipelineState()
    state.memory[0] = 11
    state.memory[1] = 4
    state.memory[2] = 14
    state.memory[3] = 7
    state.memory[4] = 931
    state.memory[5] = 12
    state.memory[6] = 152
    state.memory[7] = 172
    state.memory[8] = 201
    state.memory[9] = 213
    state.memory[10] = 3
    state.memory[10] = 5
    opcodes = {
        0x0 : 'rtype', 0x8: 'addi', 0xd :'ori', 0xe: 'xori', 0xc:'andi', 0xa:'slti',
        0x23: 'lw', 0x2b : 'sw', 0x4:'beq', 0x2:'j', 0x3 : 'jal', 0x5:'bne'
        
    }
    notWrites = [0x2b, 0x4, 0x2, 0x5]
    rtypes = {
        0x20: 'add', 0x22:'sub', 0x24:'and', 0x25: 'or', 0x2a:'slt', 0x26: 'xor', 
        0x27:'nor', 0x0:'sll', 0x2:'srl', 0x8:'jr'
        
    }
    def signed(data):
            if data & 0x8000:
                return data - (1 << 16)  
            else: return data

    def hazard_unit(ID_EX, state, EX_MEM, MEM_WB, IF_ID):
        ldHazardT = False
        ldHazardNT = False
        if IF_ID.done and ID_EX.done:
            memReadT= opcodes[ID_EX.instruction1T.opcode] == 'lw'
            if memReadT and ((IF_ID.rs1T == ID_EX.destreg1T) or (opcodes[IF_ID.instruction1T.opcode] == 'rtype' and (IF_ID.rt1T == ID_EX.destreg1T))):
                ldHazardT = True
            if memReadT and ((IF_ID.rs2T == ID_EX.destreg1T) or (opcodes[IF_ID.instruction2T.opcode] == 'rtype' and (IF_ID.rt2T == ID_EX.destreg1T))):
                ldHazardT = True
            if memReadT and ((IF_ID.rs1T == ID_EX.destreg2T) or (opcodes[IF_ID.instruction1T.opcode] == 'rtype' and (IF_ID.rt1T == ID_EX.destreg2T))):
                ldHazardT = True
            if memReadT and ((IF_ID.rs2T == ID_EX.destreg2T) or (opcodes[IF_ID.instruction2T.opcode] == 'rtype' and (IF_ID.rt2T == ID_EX.destreg2T))):
                ldHazardT = True
            memReadNT= opcodes[ID_EX.instruction1NT.opcode] == 'lw'
            if memReadNT and ((IF_ID.rs1NT == ID_EX.destreg1NT) or (opcodes[IF_ID.instruction1NT.opcode] == 'rtype' and (IF_ID.rt1NT == ID_EX.destreg1NT))):
                ldHazardNT = True
            if memReadNT and ((IF_ID.rs2NT == ID_EX.destreg1NT) or (opcodes[IF_ID.instruction2NT.opcode] == 'rtype' and (IF_ID.rt2NT == ID_EX.destreg1NT))):
                ldHazardNT = True
            if memReadNT and ((IF_ID.rs1NT == ID_EX.destreg2NT) or (opcodes[IF_ID.instruction1NT.opcode] == 'rtype' and (IF_ID.rt1NT == ID_EX.destreg2NT))):
                ldHazardNT = True
            if memReadNT and ((IF_ID.rs2NT == ID_EX.destreg2NT) or (opcodes[IF_ID.instruction2NT.opcode] == 'rtype' and (IF_ID.rt2NT == ID_EX.destreg2NT))):
                ldHazardNT = True
            
        return ldHazardT, ldHazardNT

    def forwarding_unit(EX_MEM, MEM_WB, ID_EX, state):
        if not EX_MEM.done and MEM_WB.done and ID_EX.done:
            writeex1 = 1 if EX_MEM.instruction1.opcode not in notWrites else 0
            writewb1 = 1 if MEM_WB.instruction1.opcode not in notWrites else 0
            writeex2 = 1 if EX_MEM.instruction2.opcode not in notWrites else 0
            writewb2 = 1 if MEM_WB.instruction2.opcode not in notWrites else 0
            #Taken path forwarding
            if writeex1 and EX_MEM.destreg1 == ID_EX.rs1T and EX_MEM.destreg1 != 0:
                op1T = EX_MEM.data1 
            elif writewb1 and MEM_WB.destreg1 == ID_EX.rs1T and MEM_WB.destreg1 !=0:
                op1T = MEM_WB.data1
            else: op1T = state.registers[ID_EX.instruction1T.rs]     
            if writeex2 and EX_MEM.destreg2 == ID_EX.rs1T and EX_MEM.destreg2 != 0:
                op1T = EX_MEM.data2 
            elif writewb2 and MEM_WB.destreg2 == ID_EX.rs1T and MEM_WB.destreg2 !=0:
                op1T = MEM_WB.data2
            
            if writeex1 and EX_MEM.destreg1 == ID_EX.rs2T and EX_MEM.destreg1 != 0:
                op1_2T = EX_MEM.data1 
            elif writewb1 and MEM_WB.destreg1 == ID_EX.rs2T and MEM_WB.destreg1 !=0:
                op1_2T = MEM_WB.data1
            else: op1_2T = state.registers[ID_EX.instruction2T.rs]
            
            if writeex2 and EX_MEM.destreg2 == ID_EX.rs2T and EX_MEM.destreg2 != 0:
                op1_2T = EX_MEM.data2 
            elif writewb2 and MEM_WB.destreg2 == ID_EX.rs2T and MEM_WB.destreg2 !=0:
                op1_2T = MEM_WB.data2


            if writeex1 and EX_MEM.destreg1 == ID_EX.rt1T and EX_MEM.destreg1 != 0:
                op2T = EX_MEM.data1 
            elif writewb1 and MEM_WB.destreg1 == ID_EX.rt1T and MEM_WB.destreg1 !=0:
                op2T = MEM_WB.data1
            else: op2T = state.registers[ID_EX.instruction1T.rt]
            if writeex2 and EX_MEM.destreg2 == ID_EX.rt1T and EX_MEM.destreg2 != 0:
                op2T = EX_MEM.data2 
            elif writewb2 and MEM_WB.destreg2 == ID_EX.rt1T and MEM_WB.destreg2 !=0:
                op2T = MEM_WB.data2
            
            
            if writeex1 and EX_MEM.destreg1 == ID_EX.rt2T and EX_MEM.destreg1 != 0:
                op2_2T = EX_MEM.data1 
            elif writewb1 and MEM_WB.destreg1 == ID_EX.rt2T and MEM_WB.destreg1 !=0:
                op2_2T = MEM_WB.data1
            else: op2_2T = state.registers[ID_EX.instruction2T.rt]
            if writeex2 and EX_MEM.destreg2 == ID_EX.rt2T and EX_MEM.destreg2 != 0:
                op2_2T = EX_MEM.data2 
            elif writewb2 and MEM_WB.destreg2 == ID_EX.rt2T and MEM_WB.destreg2 !=0:
                op2_2T = MEM_WB.data2
            
            
            
            #Not taken path forwarding=================================================
            if writeex1 and EX_MEM.destreg1 == ID_EX.rs1NT and EX_MEM.destreg1 != 0:
                op1NT = EX_MEM.data1 
            elif writewb1 and MEM_WB.destreg1 == ID_EX.rs1NT and MEM_WB.destreg1 !=0:
                op1NT = MEM_WB.data1
            else: op1NT = state.registers[ID_EX.instruction1NT.rs]
            if writeex2 and EX_MEM.destreg2 == ID_EX.rs1NT and EX_MEM.destreg2 != 0:
                op1NT = EX_MEM.data2 
            elif writewb2 and MEM_WB.destreg2 == ID_EX.rs1NT and MEM_WB.destreg2 !=0:
                op1NT = MEM_WB.data2
            
            
            if writeex1 and EX_MEM.destreg1 == ID_EX.rs2NT and EX_MEM.destreg1 != 0:
                op1_2NT = EX_MEM.data1 
            elif writewb1 and MEM_WB.destreg1 == ID_EX.rs2NT and MEM_WB.destreg1 !=0:
                op1_2NT = MEM_WB.data1
            else: op1_2NT = state.registers[ID_EX.instruction2NT.rs]
            if writeex2 and EX_MEM.destreg2 == ID_EX.rs2NT and EX_MEM.destreg2 != 0:
                op1_2NT = EX_MEM.data2 
            elif writewb2 and MEM_WB.destreg2 == ID_EX.rs2NT and MEM_WB.destreg2 !=0:
                op1_2NT = MEM_WB.data2
            

            if writeex1 and EX_MEM.destreg1 == ID_EX.rt1NT and EX_MEM.destreg1 != 0:
                op2NT = EX_MEM.data1 
            elif writewb1 and MEM_WB.destreg1 == ID_EX.rt1NT and MEM_WB.destreg1 !=0:
                op2NT = MEM_WB.data1
            else: op2NT = state.registers[ID_EX.instruction1NT.rt]
            if writeex2 and EX_MEM.destreg2 == ID_EX.rt1NT and EX_MEM.destreg2 != 0:
                op2NT = EX_MEM.data2 
            elif writewb2 and MEM_WB.destreg2 == ID_EX.rt1NT and MEM_WB.destreg2 !=0:
                op2NT = MEM_WB.data2
            
            
            if writeex1 and EX_MEM.destreg1 == ID_EX.rt2NT and EX_MEM.destreg1 != 0:
                op2_2NT = EX_MEM.data1 
            elif writewb1 and MEM_WB.destreg1 == ID_EX.rt2NT and MEM_WB.destreg1 !=0:
                op2_2NT = MEM_WB.data1
            else: op2_2NT = state.registers[ID_EX.instruction2NT.rt]
            if writeex2 and EX_MEM.destreg2 == ID_EX.rt2NT and EX_MEM.destreg2 != 0:
                op2_2NT = EX_MEM.data2 
            elif writewb2 and MEM_WB.destreg2 == ID_EX.rt2NT and MEM_WB.destreg2 !=0:
                op2_2NT = MEM_WB.data2
            
            
            
            return op1T, op2T, op1_2T, op2_2T, op1NT, op2NT, op1_2NT, op2_2NT
        
        else: return state.registers[ID_EX.instruction1T.rs], state.registers[ID_EX.instruction1T.rt], state.registers[ID_EX.instruction2T.rs], state.registers[ID_EX.instruction2T.rt], state.registers[ID_EX.instruction1NT.rs], state.registers[ID_EX.instruction1NT.rt], state.registers[ID_EX.instruction2NT.rs], state.registers[ID_EX.instruction2NT.rt]



    def fetch(state, instructions, IF_ID):
        IF_ID.rs1 = 0
        IF_ID.rt1 = 0
        IF_ID.rs2 = 0
        IF_ID.rt2 = 0
        IF_ID.last = 0
        if IF_ID.done:
            return
        
        if state.pcT < len(instructions):
            inst1T = Instruction(instructions[state.pcT])
        else: 
            IF_ID.last = 1
            inst1T = Instruction(0)
            
        if (state.pcT + 1) < len(instructions):
            inst2T = Instruction(instructions[state.pcT +1])
        else: 
            IF_ID.last = 1
            inst2T = Instruction(0)
            
        if state.pcNT < len(instructions):
            inst1NT = Instruction(instructions[state.pcNT])
        else: 
            IF_ID.last = 1
            inst1NT = Instruction(0)  
            
        if (state.pcNT + 1) < len(instructions):
            inst2NT = Instruction(instructions[state.pcNT +1])
        else: 
            IF_ID.last = 1
            inst2NT = Instruction(0)
            
        if state.ifidFlushT or state.ifidFlushNT:
            if state.ifidFlushT:
                IF_ID.last = 0
                inst1T = Instruction(0)
                inst2T = Instruction(0)
                state.ifidFlushT = 0
            if state.ifidFlushNT:
                IF_ID.last = 0
                inst1NT = Instruction(0)
                inst2NT = Instruction(0)
                state.ifidFlushNT = 0
            
        #Taken Path=============================
        IF_ID.thisPCT = state.pcT
        IF_ID.instruction1T = inst1T
        IF_ID.instructionVal1T = inst1T.instructionVal
        IF_ID.instruction2T = inst2T
        IF_ID.instructionVal2T = inst2T.instructionVal
        if ((opcodes[inst2T.opcode] == 'beq' or opcodes[inst2T.opcode] =='bne' )):
            state.branchInstruction +=1
        IF_ID.rs1T = inst1T.rs
        IF_ID.rt1T = inst1T.rt
        IF_ID.rs2T = inst2T.rs
        IF_ID.rt2T = inst2T.rt
        IF_ID.pcp2T = state.pcT+2
        #Statically assume taken
        if ((opcodes[inst2T.opcode] == 'beq' or opcodes[inst2T.opcode] =='bne' )):
            state.pcT = state.pcT +2+ signed(inst2T.imm )& 0b1111111111
            
        elif opcodes[inst2T.opcode] == 'j' or opcodes[inst2T.opcode] =='jal':
            state.pcT = inst2T.imm &0b1111111111
            
        elif opcodes[inst2T.opcode] == 'rtype' and rtypes[inst2T.funct] == 'jr':
            state.pcT = state.registers[inst2T.rs2] & 0b1111111111
            
        else: 
            state.pcT += 2
            
        #Not taken Path=========================
        IF_ID.thisPCNT = state.pcNT
        IF_ID.instruction1NT = inst1NT
        IF_ID.instructionVal1NT = inst1NT.instructionVal
        IF_ID.instruction2NT = inst2NT
        IF_ID.instructionVal2NT = inst2NT.instructionVal
        if ((opcodes[inst2NT.opcode] == 'beq' or opcodes[inst2NT.opcode] =='bne' )):
            state.branchInstruction +=1
        IF_ID.rs1NT = inst1NT.rs
        IF_ID.rt1NT = inst1NT.rt
        IF_ID.rs2NT = inst2NT.rs
        IF_ID.rt2NT = inst2NT.rt
        IF_ID.pcp2NT = state.pcNT+2
        if opcodes[inst2NT.opcode] == 'j' or opcodes[inst2NT.opcode] =='jal':
            state.pcNT = inst2NT.imm &0b1111111111
        elif opcodes[inst2NT.opcode] == 'rtype' and rtypes[inst2NT.funct] == 'jr':
            state.pcNT = state.registers[inst2NT.rs] & 0b1111111111
        else: 
            state.pcNT += 2
                
        IF_ID.nextpcT = state.pcT
        IF_ID.nextpcNT = state.pcNT #The taken path takes this value if the its branch was incorrect
        IF_ID.done = 1



    def decode(state, IF_ID, ID_EX):
        ID_EX.readData1_1T = 0
        ID_EX.readData2_1T = 0
        ID_EX.imm_1T = 0
        ID_EX.last =0
        ID_EX.rs1T = 0
        ID_EX.rt1T = 0
        ID_EX.rd1T = 0
        ID_EX.thisPCT = 0
        ID_EX.pcp2T = 0
        ID_EX.destreg1T = 0
        ID_EX.instruction1T = Instruction(0)
        ID_EX.readData1_2T = 0
        ID_EX.readData2_2T = 0
        ID_EX.imm_2T = 0
        ID_EX.rs2T = 0
        ID_EX.rt2T = 0
        ID_EX.rd2T = 0
        ID_EX.destreg2T = 0
        ID_EX.instruction2T = Instruction(0)
        ID_EX.readData1_1NT = 0
        ID_EX.readData2_1NT = 0
        ID_EX.imm_1NT = 0
        ID_EX.last =0
        ID_EX.rs1NT = 0
        ID_EX.rt1NT = 0
        ID_EX.rd1NT = 0
        ID_EX.thisPCNT = 0
        ID_EX.pcp2NT = 0
        ID_EX.destreg1NT = 0
        ID_EX.instruction1NT = Instruction(0)
        ID_EX.readData1_2NT = 0
        ID_EX.readData2_2NT = 0
        ID_EX.imm_2NT = 0
        ID_EX.rs2NT = 0
        ID_EX.rt2NT = 0
        ID_EX.rd2NT = 0
        ID_EX.destreg2NT = 0
        ID_EX.instruction2NT = Instruction(0)
        if not IF_ID.done: #checks if IFID is fetching another instruction or not
            return
        
        inst1T = IF_ID.instruction1T
        inst2T = IF_ID.instruction2T
        if state.idexFlushT:
            ID_EX.instruction1T = Instruction(0)
            ID_EX.instructionVal1T = 0
            inst1T = Instruction(0)
            ID_EX.instruction2T = Instruction(0)
            ID_EX.instructionVal2T = 0
            inst2T = Instruction(0)
            state.idexFlushT = 0
        
        if opcodes[inst1T.opcode] == 'rtype':
            ID_EX.readData1_1T = state.registers[inst1T.rs]
            ID_EX.readData2_1T = state.registers[inst1T.rt]
        else:
            ID_EX.imm_1T= signed(inst1T.imm)
            ID_EX.readData1_1T = state.registers[inst1T.rs]
            
        if opcodes[inst2T.opcode] == 'rtype':
            ID_EX.readData1_2T = state.registers[inst2T.rs]
            ID_EX.readData2_2T = state.registers[inst2T.rt]
        else:
            ID_EX.imm_2T= signed(inst2T.imm)
            ID_EX.readData1_2T = state.registers[inst2T.rs]
            
        ID_EX.instruction1T = inst1T
        ID_EX.instruction2T = inst2T
        
        
        ID_EX.instructionVal1T = inst1T.instructionVal
        ID_EX.instructionVal2T = inst2T.instructionVal
        
        ID_EX.rs1T = inst1T.rs
        ID_EX.rt1T = inst1T.rt
        ID_EX.rs2T = inst2T.rs
        ID_EX.rt2T = inst2T.rt
        
        validRt1T = opcodes[inst1T.opcode] == 'rtype' or opcodes[inst1T.opcode] =='bne' or opcodes[inst1T.opcode] == 'beq'
        ID_EX.destreg1T = inst1T.rd if validRt1T else inst1T.rt
        validRt2T = opcodes[inst2T.opcode] == 'rtype' or opcodes[inst2T.opcode] =='bne' or opcodes[inst2T.opcode] == 'beq'
        ID_EX.destreg2T = inst2T.rd if validRt2T else inst2T.rt
        
        ID_EX.rd1T = inst1T.rd
        ID_EX.rd2T = inst2T.rd
        #Not taken Path==============================================
        
        
        inst1NT = IF_ID.instruction1NT
        inst2NT = IF_ID.instruction2NT
        if state.idexFlushNT:
            ID_EX.instruction1NT = Instruction(0)
            ID_EX.instructionVal1NT = 0
            inst1NT = Instruction(0)
            ID_EX.instruction2NT = Instruction(0)
            ID_EX.instructionVal2NT = 0
            inst2NT = Instruction(0)
            state.idexFlushNT = 0

        
        if opcodes[inst1NT.opcode] == 'rtype':
            ID_EX.readData1_1NT = state.registers[inst1NT.rs]
            ID_EX.readData2_1NT = state.registers[inst1NT.rt]
        else:
            ID_EX.imm_1NT= signed(inst1NT.imm)
            ID_EX.readData1_1NT = state.registers[inst1NT.rs]
            
        if opcodes[inst2NT.opcode] == 'rtype':
            ID_EX.readData1_2NT = state.registers[inst2NT.rs]
            ID_EX.readData2_2NT = state.registers[inst2NT.rt]
        else:
            ID_EX.imm_2NT= signed(inst2NT.imm)
            ID_EX.readData1_2NT = state.registers[inst2NT.rs]
            
        ID_EX.instruction1NT = inst1NT
        ID_EX.instruction2NT = inst2NT
        
        
        ID_EX.instructionVal1NT = inst1NT.instructionVal
        ID_EX.instructionVal2NT = inst2NT.instructionVal
        
        ID_EX.rs1NT = inst1NT.rs
        ID_EX.rt1NT = inst1NT.rt
        ID_EX.rs2NT = inst2NT.rs
        ID_EX.rt2NT = inst2NT.rt
        
        validRt1NT = opcodes[inst1NT.opcode] == 'rtype' or opcodes[inst1NT.opcode] =='bne' or opcodes[inst1NT.opcode] == 'beq'
        ID_EX.destreg1NT = inst1NT.rd if validRt1NT else inst1NT.rt
        validRt2NT = opcodes[inst2NT.opcode] == 'rtype' or opcodes[inst2NT.opcode] =='bne' or opcodes[inst2NT.opcode] == 'beq'
        ID_EX.destreg2NT = inst2NT.rd if validRt2NT else inst2NT.rt
        
        ID_EX.rd1NT = inst1NT.rd
        ID_EX.rd2NT = inst2NT.rd
        
        ID_EX.pcp2T = IF_ID.pcp2T
        ID_EX.pcp2NT = IF_ID.pcp2NT
        ID_EX.last = IF_ID.last
        
        ID_EX.thisPCT = IF_ID.thisPCT
        ID_EX.thisPCNT = IF_ID.thisPCNT
        ID_EX.done = 1 #IDEX cannot decode and change its value until execute stage is done
        IF_ID.done = 0 # IFID is now allowed to fetch another instruction
        
        
        
        
    def execute(state,ID_EX, EX_MEM, IF_ID):
        if not ID_EX.done: 
            return
        EX_MEM.last =0
        EX_MEM.forwardBres1 = 0
        EX_MEM.imm1 = 0
        EX_MEM.readData1_1 = 0
        EX_MEM.instruction1 = Instruction(0)
        EX_MEM.forwardBres2 = 0
        EX_MEM.imm_2 = 0
        EX_MEM.readData1_2 = 0
        EX_MEM.instruction2 = Instruction(0)
        data1T = 0
        data2T = 0
        data1NT = 0
        data2NT = 0
        inst1T = ID_EX.instruction1T
        inst2T = ID_EX.instruction2T
        inst1NT = ID_EX.instruction1NT
        inst2NT = ID_EX.instruction2NT
        validRt1T = opcodes[inst1T.opcode] == 'rtype' or opcodes[inst1T.opcode] =='bne' or opcodes[inst1T.opcode] == 'beq'
        validRt2T = opcodes[inst2T.opcode] == 'rtype' or opcodes[inst2T.opcode] =='bne' or opcodes[inst2T.opcode] == 'beq'
        
        validRt1NT = opcodes[inst1NT.opcode] == 'rtype' or opcodes[inst1NT.opcode] =='bne' or opcodes[inst1NT.opcode] == 'beq'
        validRt2NT = opcodes[inst2NT.opcode] == 'rtype' or opcodes[inst2NT.opcode] =='bne' or opcodes[inst2NT.opcode] == 'beq'
        
        op1T, op2T, op1_2T, op2_2T, op1NT, op2NT, op1_2NT, op2_2NT = forwarding_unit(EX_MEM=EX_MEM, MEM_WB=MEM_WB, ID_EX=ID_EX, state= state)
        
        if not validRt1T: op2T = ID_EX.imm_1T
        if not validRt2T: op2_2T = ID_EX.imm_2T
        
        if not validRt1NT: op2NT = ID_EX.imm_1NT
        if not validRt2NT: op2_2NT = ID_EX.imm_2NT
        
        if opcodes[inst1T.opcode] == 'rtype':
            if rtypes[inst1T.funct] =='add':
                data1T = op1T + op2T
            elif rtypes[inst1T.funct] =='sub':
                data1T = op1T - op2T
            elif rtypes[inst1T.funct] =='and':
                data1T = op1T & op2T
            elif rtypes[inst1T.funct] =='or':
                data1T = op1T | op2T
            elif rtypes[inst1T.funct] =='slt':
                data1T = 1 if op1T<op2T else 0
            elif rtypes[inst1T.funct] =='xor':
                data1T = op1T ^ op2T
            elif rtypes[inst1T.funct] =='nor':
                data1T = ~(op1T | op2T)
            elif rtypes[inst1T.funct] =='sll':
                data1T = op1T <<inst1T.shamt
            elif rtypes[inst1T.funct] =='srl':
                data1T = op1T >> inst1T.shamt
                
        elif opcodes[inst1T.opcode] == 'addi':
            data1T = op1T+op2T
        elif opcodes[inst1T.opcode] == 'ori':
            data1T = op1T|op2T
        elif opcodes[inst1T.opcode] == 'xori':
            data1T = op1T^op2T
        elif opcodes[inst1T.opcode] == 'andi':
            data1T = op1T& op2T
        elif opcodes[inst1T.opcode] == 'slti':
            data1T = 1 if op1T<op2T else 0
        elif opcodes[inst1T.opcode] == 'sw': data1T = state.registers[inst1T.rt]
        else: data1T = 0
        
        if opcodes[inst1NT.opcode] == 'rtype':
            if rtypes[inst1NT.funct] =='add':
                data1NT = op1NT + op2NT
            elif rtypes[inst1NT.funct] =='sub':
                data1NT = op1NT - op2NT
            elif rtypes[inst1NT.funct] =='and':
                data1NT = op1NT & op2NT
            elif rtypes[inst1NT.funct] =='or':
                data1NT = op1NT | op2NT
            elif rtypes[inst1NT.funct] =='slt':
                data1NT = 1 if op1NT<op2NT else 0
            elif rtypes[inst1NT.funct] =='xor':
                data1NT = op1NT ^ op2NT
            elif rtypes[inst1NT.funct] =='nor':
                data1NT = ~(op1NT | op2NT)
            elif rtypes[inst1NT.funct] =='sll':
                data1NT = op1NT <<inst1NT.shamt
            elif rtypes[inst1NT.funct] =='srl':
                data1NT = op1NT >> inst1NT.shamt
        elif opcodes[inst1NT.opcode] == 'addi':
            data1NT = op1NT+op2NT
        elif opcodes[inst1NT.opcode] == 'ori':
            data1NT = op1NT|op2NT
        elif opcodes[inst1NT.opcode] == 'xori':
            data1NT = op1NT^op2NT
        elif opcodes[inst1NT.opcode] == 'andi':
            data1NT = op1NT&op2NT
        elif opcodes[inst1NT.opcode] == 'slti':
            data1NT = 1 if op1NT<op2NT else 0
        elif opcodes[inst1NT.opcode] == 'sw': data1NT = state.registers[inst1NT.rt]
        else: data1NT = 0
        
        
        if opcodes[inst2T.opcode] == 'rtype':
            if rtypes[inst2T.funct] =='add':
                data2T = op1_2T + op2_2T
            elif rtypes[inst2T.funct] =='sub':
                data2T = op1_2T - op2_2T
            elif rtypes[inst2T.funct] =='and':
                data2T = op1_2T & op2_2T
            elif rtypes[inst2T.funct] =='or':
                data2T = op1_2T | op2_2T
            elif rtypes[inst2T.funct] =='slt':
                data2T = 1 if op1_2T<op2_2T else 0
            elif rtypes[inst2T.funct] =='xor':
                data2T = op1_2T ^ op2_2T
            elif rtypes[inst2T.funct] =='nor':
                data2T = ~(op1_2T| op2_2T)
            elif rtypes[inst2T.funct] =='sll':
                data2T = op1_2T <<inst2T.shamt
            elif rtypes[inst2T.funct] =='srl':
                data2T = op1_2T >> inst2T.shamt
                
        elif opcodes[inst2T.opcode] == 'addi':
            data2T = op1_2T+op2_2T
        elif opcodes[inst2T.opcode] == 'ori':
            data2T = op1_2T|op2_2T
        elif opcodes[inst2T.opcode] == 'xori':
            data2T = op1_2T^op2_2T
        elif opcodes[inst2T.opcode] == 'andi':
            data2T = op1_2T&op2_2T
        elif opcodes[inst2T.opcode] == 'slti':
            data2T = 1 if op1_2T<op2_2T else 0
        elif opcodes[inst2T.opcode] == 'sw': data2T = state.registers[inst2T.rt]
        else: data2T = 0
        
        if opcodes[inst2NT.opcode] == 'rtype':
            if rtypes[inst2NT.funct] =='add':
                data2NT = op1_2NT + op2_2NT
            elif rtypes[inst2NT.funct] =='sub':
                data2NT = op1_2NT - op2_2NT
            elif rtypes[inst2NT.funct] =='and':
                data2NT = op1_2NT & op2_2NT
            elif rtypes[inst2NT.funct] =='or':
                data2NT = op1_2NT | op2_2NT
            elif rtypes[inst2NT.funct] =='slt':
                data2NT = 1 if op1_2NT<op2_2NT else 0
            elif rtypes[inst2NT.funct] =='xor':
                data2NT = op1_2NT ^ op2_2NT
            elif rtypes[inst2NT.funct] =='nor':
                data2NT = ~(op1_2NT| op2_2NT)
            elif rtypes[inst2NT.funct] =='sll':
                data2NT = op1_2NT <<inst2NT.shamt
            elif rtypes[inst2NT.funct] =='srl':
                data2NT = op1_2NT >> inst2NT.shamt
        elif opcodes[inst2NT.opcode] == 'addi':
            data2NT = op1_2NT+op2_2NT
        elif opcodes[inst2NT.opcode] == 'ori':
            data2NT = op1_2NT|op2_2NT
        elif opcodes[inst2NT.opcode] == 'xori':
            data2NT = op1_2NT^op2_2NT
        elif opcodes[inst2NT.opcode] == 'andi':
            data2NT = op1_2NT&op2_2NT
        elif opcodes[inst2NT.opcode] == 'slti':
            data2NT = 1 if op1_2NT<op2_2NT else 0
        elif opcodes[inst2NT.opcode] == 'sw': data2NT = state.registers[inst2NT.rt]
        else: data2NT = 0
        

        if(opcodes[inst2T.opcode] == 'bne'):
            if op1_2T == op2_2T:
                state.taken = 0
            else: state.taken = 1
        elif(opcodes[inst2T.opcode] == 'beq'):
            if op1_2T == op2_2T:
                state.taken = 1
            else: state.taken = 0
            
        if(opcodes[inst2NT.opcode] == 'bne'):
            if op1_2NT == op2_2NT:
                state.taken = 0
            else: state.taken = 1
        elif(opcodes[inst2NT.opcode] == 'beq'):
            if op1_2NT == op2_2NT:
                state.taken = 1
            else: state.taken = 0  
            
            
            
        if opcodes[inst2T.opcode] == 'bne' or opcodes[inst2T.opcode] == 'beq':
            if state.taken:
                if IF_ID.inst2T and opcodes[IF_ID.inst2T.opcode] == 'beq' or opcodes[IF_ID.inst2T.opcode] == 'beq':
                    state.pcNT = IF_ID.pcp2T
                    state.idexFlushNT = 1
                else:
                    state.pcNT = state.pcT
                    state.idexFlushNT = 1

            else:
                state.pcT = state.pcNT
                state.idexFlushT = 1
                
        if opcodes[inst2NT.opcode] == 'bne' or opcodes[inst2NT.opcode] == 'beq':
            if state.taken:
                state.pcNT = state.pcT
                state.idexFlushNT = 1
            else:
                if IF_ID.inst2NT and opcodes[IF_ID.inst2NT.opcode] == 'beq' or opcodes[IF_ID.inst2NT.opcode] == 'beq' :
                    state.pcT = IF_ID.pcp2NT +signed(IF_ID.inst2NT.imm )& 0b1111111111
                    state.idexFlushT = 1
                else:
                    state.pcT = state.pcNT
                    state.idexFlushT = 1   
        
                
        taken = state.taken              
        EX_MEM.instruction1 = inst1T if taken else inst1NT
        EX_MEM.instructionVal1 = inst1T.instructionVal if taken else inst1NT.instructionVal
        
        EX_MEM.imm_1 = ID_EX.imm_1T if taken else ID_EX.imm_1NT
        
        EX_MEM.instruction2 = inst2T if taken else inst2NT
        EX_MEM.instructionVal2 = inst2T.instructionVal if taken else inst2NT.instructionVal
        
        EX_MEM.imm_2 = ID_EX.imm_2T if taken else ID_EX.imm_2NT
        
        EX_MEM.readData1_1 = ID_EX.readData1_1T if taken else ID_EX.readData1_1NT 
        EX_MEM.readData1_2 = ID_EX.readData1_2T if taken else ID_EX.readData1_2NT
        
        EX_MEM.rs1 = inst1T.rs if taken else inst1NT.rs 
        EX_MEM.rt1 = inst1T.rt if taken else inst1NT.rt
        EX_MEM.rd1 = inst1T.rd if taken else inst1NT.rd
        
        EX_MEM.rs2 = inst2T.rs if taken else inst2NT.rs 
        EX_MEM.rt2 = inst2T.rt if taken else inst2NT.rt
        EX_MEM.rd2 = inst2T.rd if taken else inst2NT.rd
                
        EX_MEM.op1 = op1T if taken else op1NT    
        EX_MEM.op2 = op2T if taken else op2NT
        EX_MEM.op1_2 = op1_2T if taken else op1_2NT
        EX_MEM.op2_2 = op2_2T if taken else op1_2NT

        EX_MEM.data1 = data1T if taken else data1NT
        EX_MEM.data2 = data2T if taken else data2NT
        
        EX_MEM.last = ID_EX.last
        EX_MEM.thisPC = ID_EX.thisPCT if taken else ID_EX.thisPCNT
        EX_MEM.destreg1 = (inst1T.rd if validRt1T else inst1T.rt) if taken else (inst1NT.rd if validRt1NT else inst1NT.rt)
        EX_MEM.destreg2 = (inst2T.rd if validRt2T else inst2T.rt) if taken else (inst2NT.rd if validRt2NT else inst2NT.rt)
        
        EX_MEM.pcp2 = ID_EX.pcp2T if taken else ID_EX.pcp2NT
        EX_MEM.done = 1
        ID_EX.done = 0
            
            
                
            
                
    def memory (state, EX_MEM, MEM_WB):
        MEM_WB.last =0
        if not EX_MEM.done: #checks if exeucte is executing or not
            return
        inst1 = EX_MEM.instruction1
        op1 = 0
        op12 = 0
        datastored = 0
        datastored2 = 0
        inst2 = EX_MEM.instruction2
        if MEM_WB.instruction1:
            writewb1 = 1 if MEM_WB.instruction1.opcode not in notWrites else 0
        if MEM_WB.instruction2:   
            writewb2 = 1 if MEM_WB.instruction2.opcode not in notWrites else 0
            
        if opcodes[inst1.opcode] == 'lw':
            data1 = state.memory[EX_MEM.op1 + EX_MEM.imm_1]
        elif opcodes[inst1.opcode] == 'sw':
            if writewb2 and MEM_WB.destreg2 == inst1.rs and MEM_WB.destreg2 !=0:
                op1 = MEM_WB.data2  
            elif writewb1 and MEM_WB.destreg1 == inst1.rs and MEM_WB.destreg1 !=0:
                op1 = MEM_WB.data1
            else:
                op1 = EX_MEM.op1  
                
            if writewb2 and MEM_WB.destreg2 == inst1.rt and MEM_WB.destreg2 !=0:
                datastored = MEM_WB.data2
            elif writewb1 and MEM_WB.destreg1 == inst1.rt and MEM_WB.destreg1 !=0:
                datastored = MEM_WB.data1
            else:
                datastored = state.registers[inst1.rt]
            state.memory[op1 + EX_MEM.imm_1] = datastored
           
        if opcodes[inst2.opcode] == 'lw':
            data2 = state.memory[EX_MEM.op1_2 + EX_MEM.imm_2]
            
        elif opcodes[inst2.opcode] == 'sw':
            
            if writewb2 and MEM_WB.destreg2 == inst2.rs and MEM_WB.destreg2 !=0:
                op12 = MEM_WB.data2  
            elif writewb1 and MEM_WB.destreg1 == inst2.rs and MEM_WB.destreg1 !=0:
                op12 = MEM_WB.data1
            else:
                op12 = EX_MEM.op1_2  
            if writewb2 and MEM_WB.destreg2 == inst2.rt and MEM_WB.destreg2 !=0:
                datastored2 = MEM_WB.data2
            elif writewb1 and MEM_WB.destreg1 == inst2.rt and MEM_WB.destreg1 !=0:
                datastored2 = MEM_WB.data1
            else:
                datastored2 = state.registers[inst2.rt]
                
            state.memory[op12 + EX_MEM.imm_2] = datastored2
        
        MEM_WB.instruction1 = inst1
        MEM_WB.instructionVal1 = inst1.instructionVal
        MEM_WB.instruction2 = inst2
        MEM_WB.instructionVal2 = inst2.instructionVal
        MEM_WB.data1 = EX_MEM.data1 if opcodes[inst1.opcode] != 'lw' else data1
        MEM_WB.data2 = EX_MEM.data2 if opcodes[inst2.opcode] != 'lw' else data2
        MEM_WB.rs1 = inst1.rs
        MEM_WB.rt1 = inst1.rt
        MEM_WB.rd1 = inst1.rd
        MEM_WB.rs2 = inst2.rs
        MEM_WB.rt2 = inst2.rt
        MEM_WB.rd2 = inst2.rd
        
        MEM_WB.last = EX_MEM.last
        MEM_WB.thisPC = EX_MEM.thisPC
        MEM_WB.destreg1 = EX_MEM.destreg1
        MEM_WB.destreg2 = EX_MEM.destreg2
        MEM_WB.done = 1
        EX_MEM.done =0
        
        
    opcodes = {
        0x0 : 'rtype', 0x8: 'addi', 0xd :'ori', 0xe: 'xori', 0xc:'andi', 0xa:'slti',
        0x23: 'lw', 0x2b : 'sw', 0x4:'beq', 0x2:'j', 0x3 : 'jal', 0x5:'bne'
        
    }


    def writeBack(state, MEM_WB):
        if not MEM_WB.done:
            return
        inst1 = MEM_WB.instruction1
        inst2 = MEM_WB.instruction2
        if opcodes[inst1.opcode] != 'sw' and opcodes[inst1.opcode] !='j' and opcodes[inst1.opcode] !='jal' and opcodes[inst1.opcode] !='bne' and opcodes[inst1.opcode] !='beq':
            state.registers[inst1.rd if opcodes[inst1.opcode] == 'rtype' else inst1.rt] = MEM_WB.data1
            
        if opcodes[inst2.opcode] != 'sw' and opcodes[inst2.opcode] !='j' and opcodes[inst2.opcode] !='jal' and opcodes[inst2.opcode] !='bne' and opcodes[inst2.opcode] !='beq':
            state.registers[inst2.rd if opcodes[inst2.opcode] == 'rtype' else inst2.rt] = MEM_WB.data2
            
        if opcodes[inst2.opcode] == 'jal':
            state.registers[31] = MEM_WB.thisPC + 2
        MEM_WB.done = 0
        
        
        
        
    def printState(stages):
        for stage, reg in stages.items():
                print(f"{stage}: \n")
                for signal, value in vars(reg).items():
                    print(f"{signal}: {value}")
                print("-"*20)
                
    def read_binary_file(filename):
        binary_values = []

        with open(filename, 'r') as file:
            for line in file:
                if '0x' in line:
                    binary_values.append(int(line.strip(), 16))
                else: 
                    binary_values.append(int(line.strip()))  # Remove any whitespace or newline characters

        return binary_values

# Example usage
    filename = "dmem.txt"
    binary_array = read_binary_file(filename)
    print(f'\nValues in the memory: \n{binary_array}\n')    
    #Initialize the pipeline state
    IF_ID = PipelineRegister()
    ID_EX = PipelineRegister()
    EX_MEM = PipelineRegister()
    MEM_WB = PipelineRegister()
    state = PipelineState()
    for i in range(len(binary_array)):
        state.memory[i] = binary_array[i]
        
    cycle = 0
    countofstalls = 0
    cycles = 5000
    stages = {'IF_ID':IF_ID, 'ID_EX': ID_EX, 'EX_MEM': EX_MEM, 'MEM_WB': MEM_WB }
    while (cycle < cycles):
        print(f"\n\n{'-' *50}")
        print(f"Cycle {cycle}")
        print(f"{'-'*50}")
        print(f"PCT: {state.pcT}")
        print(f"PCNT: {state.pcNT}")
        print(f"Taken: {state.taken}")
        if MEM_WB.last:break
        writeBack(state, MEM_WB)
        memory(state, EX_MEM, MEM_WB)
        ldHazardT, ldHazardNT = hazard_unit(ID_EX, state, EX_MEM, MEM_WB, IF_ID)
        if ldHazardT:
            state.pcT = IF_ID.thisPCT
            state.idexFlushT = 1
            print("load hazard detected")
            countofstalls +=1
        if ldHazardNT:
            state.pcNT = IF_ID.thisPCNT
            state.idexFlushNT = 1
            
        execute(state, ID_EX, EX_MEM, IF_ID)
        decode(state, IF_ID, ID_EX)
        fetch(state, instructions, IF_ID)
        
        #pipeline register states
        printState(stages)
        print(f"{"-"*50}")
        for i in range(32):
            print(f"M{i:2}: {state.registers[i]}")
        print(f"{"-"*50}")
        cycle +=1
    state.pc = 0


    def print_registers(registers):
        print("\nFinal Register Values:")
        print(f"{'-' * 50}")
        for i, value in enumerate(registers):
            print(f"R{i:2}: {value}")
        print(f"{'-' * 50}\n")

    print_registers(state.registers[0:32])

    def printMemory(memory):
        print ("\nFinal mem values:")
        print(f"{"-"*50}")
        for i in range(32):
            print(f"M{i:2}: {memory[i]}")
        print(f"{"-"*50}")
    printMemory(state.memory)
    print("cycle count: ", cycle)
    print("ld hazard count: ", countofstalls)
    print("branch flush count: ", state.branchflushcount)
    print("branch instruction count: ", state.branchInstruction )

    


            
    
state = runCpu()
# Out:
# Values in the memory:
# [0]
#
#
#
# --------------------------------------------------
# Cycle 0
# --------------------------------------------------
# PCT: 0
# PCNT: 0
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 0
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D4F0>
# instructionVal1T: 0b100000000000100000000000000101
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FAA0>
# instructionVal2T: 0b100000000000110000000000001010
# rs1T: 0
# rt1T: 2
# rs2T: 0
# rt2T: 3
# pcp2T: 2
# thisPCNT: 0
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F7A0>
# instructionVal1NT: 0b100000000000100000000000000101
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CBF0>
# instructionVal2NT: 0b100000000000110000000000001010
# rs1NT: 0
# rt1NT: 2
# rs2NT: 0
# rt2NT: 3
# pcp2NT: 2
# nextpcT: 2
# nextpcNT: 2
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 0
# pc: 0
# readData1_1T: 0
# readData2_1T: 0
# imm_1T: 0
# rs1T: 0
# rt1T: 0
# rd1T: 0
# thisPCT: 0
# pcp2T: 0
# destreg1T: 0
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C440>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 0
# rs2T: 0
# rt2T: 0
# rd2T: 0
# destreg2T: 0
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D5E0>
# readData1_1NT: 0
# readData2_1NT: 0
# imm_1NT: 0
# rs1NT: 0
# rt1NT: 0
# rd1NT: 0
# thisPCNT: 0
# pcp2NT: 0
# destreg1NT: 0
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB40>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 0
# rs2NT: 0
# rt2NT: 0
# rd2NT: 0
# destreg2NT: 0
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CDA0>
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 0
# pc: 0
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 0
# pc: 0
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 0
# M 3: 0
# M 4: 0
# M 5: 0
# M 6: 0
# M 7: 0
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 0
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 1
# --------------------------------------------------
# PCT: 2
# PCNT: 2
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 2
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB40>
# instructionVal1T: 0b110000000111110000000000000000
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DF40>
# instructionVal2T: 0b111111100000100000
# rs1T: 0
# rt1T: 31
# rs2T: 0
# rt2T: 3
# pcp2T: 4
# thisPCNT: 2
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F4A0>
# instructionVal1NT: 0b110000000111110000000000000000
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C440>
# instructionVal2NT: 0b111111100000100000
# rs1NT: 0
# rt1NT: 31
# rs2NT: 0
# rt2NT: 3
# pcp2NT: 4
# nextpcT: 4
# nextpcNT: 4
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 0
# readData2_1T: 0
# imm_1T: 5
# rs1T: 0
# rt1T: 2
# rd1T: 0
# thisPCT: 0
# pcp2T: 2
# destreg1T: 2
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D4F0>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 10
# rs2T: 0
# rt2T: 3
# rd2T: 0
# destreg2T: 3
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FAA0>
# readData1_1NT: 0
# readData2_1NT: 0
# imm_1NT: 5
# rs1NT: 0
# rt1NT: 2
# rd1NT: 0
# thisPCNT: 0
# pcp2NT: 2
# destreg1NT: 2
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F7A0>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 10
# rs2NT: 0
# rt2NT: 3
# rd2NT: 0
# destreg2NT: 3
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CBF0>
# instructionVal1T: 0b100000000000100000000000000101
# instructionVal2T: 0b100000000000110000000000001010
# instructionVal1NT: 0b100000000000100000000000000101
# instructionVal2NT: 0b100000000000110000000000001010
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 0
# pc: 0
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 0
# pc: 0
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 0
# M 3: 0
# M 4: 0
# M 5: 0
# M 6: 0
# M 7: 0
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 0
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 2
# --------------------------------------------------
# PCT: 4
# PCNT: 4
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 4
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F7A0>
# instructionVal1T: 0b100001100000100000
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CF80>
# instructionVal2T: 0b111110001000000100000
# rs1T: 0
# rt1T: 2
# rs2T: 0
# rt2T: 31
# pcp2T: 6
# thisPCNT: 4
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E330>
# instructionVal1NT: 0b100001100000100000
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DE50>
# instructionVal2NT: 0b111110001000000100000
# rs1NT: 0
# rt1NT: 2
# rs2NT: 0
# rt2NT: 31
# pcp2NT: 6
# nextpcT: 6
# nextpcNT: 6
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 0
# readData2_1T: 0
# imm_1T: 0
# rs1T: 0
# rt1T: 31
# rd1T: 0
# thisPCT: 2
# pcp2T: 4
# destreg1T: 31
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB40>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 0
# rs2T: 0
# rt2T: 3
# rd2T: 31
# destreg2T: 31
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DF40>
# readData1_1NT: 0
# readData2_1NT: 0
# imm_1NT: 0
# rs1NT: 0
# rt1NT: 31
# rd1NT: 0
# thisPCNT: 2
# pcp2NT: 4
# destreg1NT: 31
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F4A0>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 0
# rs2NT: 0
# rt2NT: 3
# rd2NT: 31
# destreg2NT: 31
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C440>
# instructionVal1T: 0b110000000111110000000000000000
# instructionVal2T: 0b111111100000100000
# instructionVal1NT: 0b110000000111110000000000000000
# instructionVal2NT: 0b111111100000100000
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D4F0>
# instructionVal1: 0b100000000000100000000000000101
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FAA0>
# instructionVal2: 0b100000000000110000000000001010
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 0
# forwardBres2: 0
# imm_2: 10
# readData1_2: 0
# imm_1: 5
# rs1: 0
# rt1: 2
# rd1: 0
# rs2: 0
# rt2: 3
# rd2: 0
# op1: 0
# op2: 5
# op1_2: 0
# op2_2: 10
# data1: 5
# data2: 10
# thisPC: 0
# destreg1: 2
# destreg2: 3
# pcp2: 2
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 0
# pc: 0
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 0
# M 3: 0
# M 4: 0
# M 5: 0
# M 6: 0
# M 7: 0
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 0
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 3
# --------------------------------------------------
# PCT: 6
# PCNT: 6
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 6
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F4A0>
# instructionVal1T: 0b10101100000000100000000000000001
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E240>
# instructionVal2T: 0b10101100000000110000000000000010
# rs1T: 0
# rt1T: 2
# rs2T: 0
# rt2T: 3
# pcp2T: 8
# thisPCNT: 6
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CA40>
# instructionVal1NT: 0b10101100000000100000000000000001
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E930>
# instructionVal2NT: 0b10101100000000110000000000000010
# rs1NT: 0
# rt1NT: 2
# rs2NT: 0
# rt2NT: 3
# pcp2NT: 8
# nextpcT: 8
# nextpcNT: 8
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 0
# readData2_1T: 0
# imm_1T: 0
# rs1T: 0
# rt1T: 2
# rd1T: 3
# thisPCT: 4
# pcp2T: 6
# destreg1T: 3
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F7A0>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 0
# rs2T: 0
# rt2T: 31
# rd2T: 2
# destreg2T: 2
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CF80>
# readData1_1NT: 0
# readData2_1NT: 0
# imm_1NT: 0
# rs1NT: 0
# rt1NT: 2
# rd1NT: 3
# thisPCNT: 4
# pcp2NT: 6
# destreg1NT: 3
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E330>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 0
# rs2NT: 0
# rt2NT: 31
# rd2NT: 2
# destreg2NT: 2
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DE50>
# instructionVal1T: 0b100001100000100000
# instructionVal2T: 0b111110001000000100000
# instructionVal1NT: 0b100001100000100000
# instructionVal2NT: 0b111110001000000100000
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB40>
# instructionVal1: 0b110000000111110000000000000000
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DF40>
# instructionVal2: 0b111111100000100000
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 0
# forwardBres2: 0
# imm_2: 0
# readData1_2: 0
# imm_1: 0
# rs1: 0
# rt1: 31
# rd1: 0
# rs2: 0
# rt2: 3
# rd2: 31
# op1: 0
# op2: 0
# op1_2: 0
# op2_2: 10
# data1: 0
# data2: 10
# thisPC: 2
# destreg1: 31
# destreg2: 31
# pcp2: 4
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D4F0>
# instructionVal1: 0b100000000000100000000000000101
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FAA0>
# instructionVal2: 0b100000000000110000000000001010
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 1
# pc: 0
# data1: 5
# data2: 10
# rs1: 0
# rt1: 2
# rd1: 0
# rs2: 0
# rt2: 3
# rd2: 0
# thisPC: 0
# destreg1: 2
# destreg2: 3
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 0
# M 3: 0
# M 4: 0
# M 5: 0
# M 6: 0
# M 7: 0
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 0
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 4
# --------------------------------------------------
# PCT: 8
# PCNT: 8
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 8
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E330>
# instructionVal1T: 0b100000000001000000000000001111
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E5A0>
# instructionVal2T: 0b100000000001010000000000010100
# rs1T: 0
# rt1T: 4
# rs2T: 0
# rt2T: 5
# pcp2T: 10
# thisPCNT: 8
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C440>
# instructionVal1NT: 0b100000000001000000000000001111
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FAA0>
# instructionVal2NT: 0b100000000001010000000000010100
# rs1NT: 0
# rt1NT: 4
# rs2NT: 0
# rt2NT: 5
# pcp2NT: 10
# nextpcT: 10
# nextpcNT: 10
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 0
# readData2_1T: 0
# imm_1T: 1
# rs1T: 0
# rt1T: 2
# rd1T: 0
# thisPCT: 6
# pcp2T: 8
# destreg1T: 2
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F4A0>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 2
# rs2T: 0
# rt2T: 3
# rd2T: 0
# destreg2T: 3
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E240>
# readData1_1NT: 0
# readData2_1NT: 0
# imm_1NT: 1
# rs1NT: 0
# rt1NT: 2
# rd1NT: 0
# thisPCNT: 6
# pcp2NT: 8
# destreg1NT: 2
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CA40>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 2
# rs2NT: 0
# rt2NT: 3
# rd2NT: 0
# destreg2NT: 3
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E930>
# instructionVal1T: 0b10101100000000100000000000000001
# instructionVal2T: 0b10101100000000110000000000000010
# instructionVal1NT: 0b10101100000000100000000000000001
# instructionVal2NT: 0b10101100000000110000000000000010
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F7A0>
# instructionVal1: 0b100001100000100000
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CF80>
# instructionVal2: 0b111110001000000100000
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 0
# forwardBres2: 0
# imm_2: 0
# readData1_2: 0
# imm_1: 0
# rs1: 0
# rt1: 2
# rd1: 3
# rs2: 0
# rt2: 31
# rd2: 2
# op1: 0
# op2: 5
# op1_2: 0
# op2_2: 10
# data1: 5
# data2: 10
# thisPC: 4
# destreg1: 3
# destreg2: 2
# pcp2: 6
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB40>
# instructionVal1: 0b110000000111110000000000000000
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DF40>
# instructionVal2: 0b111111100000100000
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 1
# pc: 0
# data1: 0
# data2: 10
# rs1: 0
# rt1: 31
# rd1: 0
# rs2: 0
# rt2: 3
# rd2: 31
# thisPC: 2
# destreg1: 31
# destreg2: 31
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 5
# M 3: 10
# M 4: 0
# M 5: 0
# M 6: 0
# M 7: 0
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 0
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 5
# --------------------------------------------------
# PCT: 10
# PCNT: 10
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 10
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CA40>
# instructionVal1T: 0b100001010010100000100000
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CBC0>
# instructionVal2T: 0b100000000001100000000000011001
# rs1T: 4
# rt1T: 5
# rs2T: 0
# rt2T: 6
# pcp2T: 12
# thisPCNT: 10
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DE50>
# instructionVal1NT: 0b100001010010100000100000
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DF40>
# instructionVal2NT: 0b100000000001100000000000011001
# rs1NT: 4
# rt1NT: 5
# rs2NT: 0
# rt2NT: 6
# pcp2NT: 12
# nextpcT: 12
# nextpcNT: 12
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 0
# readData2_1T: 0
# imm_1T: 15
# rs1T: 0
# rt1T: 4
# rd1T: 0
# thisPCT: 8
# pcp2T: 10
# destreg1T: 4
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E330>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 20
# rs2T: 0
# rt2T: 5
# rd2T: 0
# destreg2T: 5
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E5A0>
# readData1_1NT: 0
# readData2_1NT: 0
# imm_1NT: 15
# rs1NT: 0
# rt1NT: 4
# rd1NT: 0
# thisPCNT: 8
# pcp2NT: 10
# destreg1NT: 4
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C440>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 20
# rs2NT: 0
# rt2NT: 5
# rd2NT: 0
# destreg2NT: 5
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FAA0>
# instructionVal1T: 0b100000000001000000000000001111
# instructionVal2T: 0b100000000001010000000000010100
# instructionVal1NT: 0b100000000001000000000000001111
# instructionVal2NT: 0b100000000001010000000000010100
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F4A0>
# instructionVal1: 0b10101100000000100000000000000001
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E240>
# instructionVal2: 0b10101100000000110000000000000010
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 0
# forwardBres2: 0
# imm_2: 2
# readData1_2: 0
# imm_1: 1
# rs1: 0
# rt1: 2
# rd1: 0
# rs2: 0
# rt2: 3
# rd2: 0
# op1: 0
# op2: 1
# op1_2: 0
# op2_2: 2
# data1: 5
# data2: 10
# thisPC: 6
# destreg1: 2
# destreg2: 3
# pcp2: 8
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F7A0>
# instructionVal1: 0b100001100000100000
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CF80>
# instructionVal2: 0b111110001000000100000
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 1
# pc: 0
# data1: 5
# data2: 10
# rs1: 0
# rt1: 2
# rd1: 3
# rs2: 0
# rt2: 31
# rd2: 2
# thisPC: 4
# destreg1: 3
# destreg2: 2
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 5
# M 3: 10
# M 4: 0
# M 5: 0
# M 6: 0
# M 7: 0
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 10
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 6
# --------------------------------------------------
# PCT: 12
# PCNT: 12
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 12
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C440>
# instructionVal1T: 0b101001000010000000100010
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C6E0>
# instructionVal2T: 0b100000000001110000000000011110
# rs1T: 5
# rt1T: 4
# rs2T: 0
# rt2T: 7
# pcp2T: 14
# thisPCNT: 12
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E930>
# instructionVal1NT: 0b101001000010000000100010
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CF80>
# instructionVal2NT: 0b100000000001110000000000011110
# rs1NT: 5
# rt1NT: 4
# rs2NT: 0
# rt2NT: 7
# pcp2NT: 14
# nextpcT: 14
# nextpcNT: 14
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 0
# readData2_1T: 0
# imm_1T: 0
# rs1T: 4
# rt1T: 5
# rd1T: 5
# thisPCT: 10
# pcp2T: 12
# destreg1T: 5
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CA40>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 25
# rs2T: 0
# rt2T: 6
# rd2T: 0
# destreg2T: 6
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CBC0>
# readData1_1NT: 0
# readData2_1NT: 0
# imm_1NT: 0
# rs1NT: 4
# rt1NT: 5
# rd1NT: 5
# thisPCNT: 10
# pcp2NT: 12
# destreg1NT: 5
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DE50>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 25
# rs2NT: 0
# rt2NT: 6
# rd2NT: 0
# destreg2NT: 6
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DF40>
# instructionVal1T: 0b100001010010100000100000
# instructionVal2T: 0b100000000001100000000000011001
# instructionVal1NT: 0b100001010010100000100000
# instructionVal2NT: 0b100000000001100000000000011001
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E330>
# instructionVal1: 0b100000000001000000000000001111
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E5A0>
# instructionVal2: 0b100000000001010000000000010100
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 0
# forwardBres2: 0
# imm_2: 20
# readData1_2: 0
# imm_1: 15
# rs1: 0
# rt1: 4
# rd1: 0
# rs2: 0
# rt2: 5
# rd2: 0
# op1: 0
# op2: 15
# op1_2: 0
# op2_2: 20
# data1: 15
# data2: 20
# thisPC: 8
# destreg1: 4
# destreg2: 5
# pcp2: 10
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F4A0>
# instructionVal1: 0b10101100000000100000000000000001
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E240>
# instructionVal2: 0b10101100000000110000000000000010
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 1
# pc: 0
# data1: 5
# data2: 10
# rs1: 0
# rt1: 2
# rd1: 0
# rs2: 0
# rt2: 3
# rd2: 0
# thisPC: 6
# destreg1: 2
# destreg2: 3
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 10
# M 3: 5
# M 4: 0
# M 5: 0
# M 6: 0
# M 7: 0
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 10
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 7
# --------------------------------------------------
# PCT: 14
# PCNT: 14
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 14
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DE50>
# instructionVal1T: 0b101001000010100000100010
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C9E0>
# instructionVal2T: 0b10101100000001000000000000000011
# rs1T: 5
# rt1T: 4
# rs2T: 0
# rt2T: 4
# pcp2T: 16
# thisPCNT: 14
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FAA0>
# instructionVal1NT: 0b101001000010100000100010
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E240>
# instructionVal2NT: 0b10101100000001000000000000000011
# rs1NT: 5
# rt1NT: 4
# rs2NT: 0
# rt2NT: 4
# pcp2NT: 16
# nextpcT: 16
# nextpcNT: 16
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 0
# readData2_1T: 0
# imm_1T: 0
# rs1T: 5
# rt1T: 4
# rd1T: 4
# thisPCT: 12
# pcp2T: 14
# destreg1T: 4
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C440>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 30
# rs2T: 0
# rt2T: 7
# rd2T: 0
# destreg2T: 7
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C6E0>
# readData1_1NT: 0
# readData2_1NT: 0
# imm_1NT: 0
# rs1NT: 5
# rt1NT: 4
# rd1NT: 4
# thisPCNT: 12
# pcp2NT: 14
# destreg1NT: 4
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E930>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 30
# rs2NT: 0
# rt2NT: 7
# rd2NT: 0
# destreg2NT: 7
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CF80>
# instructionVal1T: 0b101001000010000000100010
# instructionVal2T: 0b100000000001110000000000011110
# instructionVal1NT: 0b101001000010000000100010
# instructionVal2NT: 0b100000000001110000000000011110
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CA40>
# instructionVal1: 0b100001010010100000100000
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CBC0>
# instructionVal2: 0b100000000001100000000000011001
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 0
# forwardBres2: 0
# imm_2: 25
# readData1_2: 0
# imm_1: 0
# rs1: 4
# rt1: 5
# rd1: 5
# rs2: 0
# rt2: 6
# rd2: 0
# op1: 15
# op2: 20
# op1_2: 0
# op2_2: 25
# data1: 35
# data2: 25
# thisPC: 10
# destreg1: 5
# destreg2: 6
# pcp2: 12
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E330>
# instructionVal1: 0b100000000001000000000000001111
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E5A0>
# instructionVal2: 0b100000000001010000000000010100
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 1
# pc: 0
# data1: 15
# data2: 20
# rs1: 0
# rt1: 4
# rd1: 0
# rs2: 0
# rt2: 5
# rd2: 0
# thisPC: 8
# destreg1: 4
# destreg2: 5
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 10
# M 3: 5
# M 4: 0
# M 5: 0
# M 6: 0
# M 7: 0
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 10
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 8
# --------------------------------------------------
# PCT: 16
# PCNT: 16
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 16
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E930>
# instructionVal1T: 0b10101100000001010000000000000100
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB10>
# instructionVal2T: 0b110001110011000000100110
# rs1T: 0
# rt1T: 5
# rs2T: 6
# rt2T: 7
# pcp2T: 18
# thisPCNT: 16
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DF40>
# instructionVal1NT: 0b10101100000001010000000000000100
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E5A0>
# instructionVal2NT: 0b110001110011000000100110
# rs1NT: 0
# rt1NT: 5
# rs2NT: 6
# rt2NT: 7
# pcp2NT: 18
# nextpcT: 18
# nextpcNT: 18
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 20
# readData2_1T: 15
# imm_1T: 0
# rs1T: 5
# rt1T: 4
# rd1T: 5
# thisPCT: 14
# pcp2T: 16
# destreg1T: 5
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DE50>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 3
# rs2T: 0
# rt2T: 4
# rd2T: 0
# destreg2T: 4
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C9E0>
# readData1_1NT: 20
# readData2_1NT: 15
# imm_1NT: 0
# rs1NT: 5
# rt1NT: 4
# rd1NT: 5
# thisPCNT: 14
# pcp2NT: 16
# destreg1NT: 5
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FAA0>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 3
# rs2NT: 0
# rt2NT: 4
# rd2NT: 0
# destreg2NT: 4
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E240>
# instructionVal1T: 0b101001000010100000100010
# instructionVal2T: 0b10101100000001000000000000000011
# instructionVal1NT: 0b101001000010100000100010
# instructionVal2NT: 0b10101100000001000000000000000011
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C440>
# instructionVal1: 0b101001000010000000100010
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C6E0>
# instructionVal2: 0b100000000001110000000000011110
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 0
# forwardBres2: 0
# imm_2: 30
# readData1_2: 0
# imm_1: 0
# rs1: 5
# rt1: 4
# rd1: 4
# rs2: 0
# rt2: 7
# rd2: 0
# op1: 35
# op2: 15
# op1_2: 0
# op2_2: 30
# data1: 20
# data2: 30
# thisPC: 12
# destreg1: 4
# destreg2: 7
# pcp2: 14
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CA40>
# instructionVal1: 0b100001010010100000100000
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CBC0>
# instructionVal2: 0b100000000001100000000000011001
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 1
# pc: 0
# data1: 35
# data2: 25
# rs1: 4
# rt1: 5
# rd1: 5
# rs2: 0
# rt2: 6
# rd2: 0
# thisPC: 10
# destreg1: 5
# destreg2: 6
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 10
# M 3: 5
# M 4: 15
# M 5: 20
# M 6: 0
# M 7: 0
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 10
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 9
# --------------------------------------------------
# PCT: 18
# PCNT: 18
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 18
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FAA0>
# instructionVal1T: 0b110001110011100000100110
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FC20>
# instructionVal2T: 0b0
# rs1T: 6
# rt1T: 7
# rs2T: 0
# rt2T: 0
# pcp2T: 20
# thisPCNT: 18
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F4A0>
# instructionVal1NT: 0b110001110011100000100110
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CDA0>
# instructionVal2NT: 0b0
# rs1NT: 6
# rt1NT: 7
# rs2NT: 0
# rt2NT: 0
# pcp2NT: 20
# nextpcT: 20
# nextpcNT: 20
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 0
# readData2_1T: 0
# imm_1T: 4
# rs1T: 0
# rt1T: 5
# rd1T: 0
# thisPCT: 16
# pcp2T: 18
# destreg1T: 5
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E930>
# readData1_2T: 25
# readData2_2T: 0
# imm_2T: 0
# rs2T: 6
# rt2T: 7
# rd2T: 6
# destreg2T: 6
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB10>
# readData1_1NT: 0
# readData2_1NT: 0
# imm_1NT: 4
# rs1NT: 0
# rt1NT: 5
# rd1NT: 0
# thisPCNT: 16
# pcp2NT: 18
# destreg1NT: 5
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DF40>
# readData1_2NT: 25
# readData2_2NT: 0
# imm_2NT: 0
# rs2NT: 6
# rt2NT: 7
# rd2NT: 6
# destreg2NT: 6
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E5A0>
# instructionVal1T: 0b10101100000001010000000000000100
# instructionVal2T: 0b110001110011000000100110
# instructionVal1NT: 0b10101100000001010000000000000100
# instructionVal2NT: 0b110001110011000000100110
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DE50>
# instructionVal1: 0b101001000010100000100010
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C9E0>
# instructionVal2: 0b10101100000001000000000000000011
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 20
# forwardBres2: 0
# imm_2: 3
# readData1_2: 0
# imm_1: 0
# rs1: 5
# rt1: 4
# rd1: 5
# rs2: 0
# rt2: 4
# rd2: 0
# op1: 35
# op2: 20
# op1_2: 0
# op2_2: 3
# data1: 15
# data2: 15
# thisPC: 14
# destreg1: 5
# destreg2: 4
# pcp2: 16
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C440>
# instructionVal1: 0b101001000010000000100010
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C6E0>
# instructionVal2: 0b100000000001110000000000011110
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 1
# pc: 0
# data1: 20
# data2: 30
# rs1: 5
# rt1: 4
# rd1: 4
# rs2: 0
# rt2: 7
# rd2: 0
# thisPC: 12
# destreg1: 4
# destreg2: 7
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 10
# M 3: 5
# M 4: 15
# M 5: 35
# M 6: 25
# M 7: 0
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 10
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 10
# --------------------------------------------------
# PCT: 20
# PCNT: 20
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 20
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DF40>
# instructionVal1T: 0b110001110011000000100110
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F7A0>
# instructionVal2T: 0b10101100000001110000000000000110
# rs1T: 6
# rt1T: 7
# rs2T: 0
# rt2T: 7
# pcp2T: 22
# thisPCNT: 20
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F140>
# instructionVal1NT: 0b110001110011000000100110
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C6E0>
# instructionVal2NT: 0b10101100000001110000000000000110
# rs1NT: 6
# rt1NT: 7
# rs2NT: 0
# rt2NT: 7
# pcp2NT: 22
# nextpcT: 22
# nextpcNT: 22
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 25
# readData2_1T: 30
# imm_1T: 0
# rs1T: 6
# rt1T: 7
# rd1T: 7
# thisPCT: 18
# pcp2T: 20
# destreg1T: 7
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FAA0>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 0
# rs2T: 0
# rt2T: 0
# rd2T: 0
# destreg2T: 0
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FC20>
# readData1_1NT: 25
# readData2_1NT: 30
# imm_1NT: 0
# rs1NT: 6
# rt1NT: 7
# rd1NT: 7
# thisPCNT: 18
# pcp2NT: 20
# destreg1NT: 7
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F4A0>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 0
# rs2NT: 0
# rt2NT: 0
# rd2NT: 0
# destreg2NT: 0
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CDA0>
# instructionVal1T: 0b110001110011100000100110
# instructionVal2T: 0b0
# instructionVal1NT: 0b110001110011100000100110
# instructionVal2NT: 0b0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E930>
# instructionVal1: 0b10101100000001010000000000000100
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB10>
# instructionVal2: 0b110001110011000000100110
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 0
# forwardBres2: 0
# imm_2: 0
# readData1_2: 25
# imm_1: 4
# rs1: 0
# rt1: 5
# rd1: 0
# rs2: 6
# rt2: 7
# rd2: 6
# op1: 0
# op2: 4
# op1_2: 25
# op2_2: 30
# data1: 35
# data2: 7
# thisPC: 16
# destreg1: 5
# destreg2: 6
# pcp2: 18
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DE50>
# instructionVal1: 0b101001000010100000100010
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C9E0>
# instructionVal2: 0b10101100000001000000000000000011
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 1
# pc: 0
# data1: 15
# data2: 15
# rs1: 5
# rt1: 4
# rd1: 5
# rs2: 0
# rt2: 4
# rd2: 0
# thisPC: 14
# destreg1: 5
# destreg2: 4
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 10
# M 3: 5
# M 4: 20
# M 5: 35
# M 6: 25
# M 7: 30
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 10
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 11
# --------------------------------------------------
# PCT: 22
# PCNT: 22
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 22
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CA40>
# instructionVal1T: 0b10101100000001100000000000000101
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CBF0>
# instructionVal2T: 0b0
# rs1T: 0
# rt1T: 6
# rs2T: 0
# rt2T: 0
# pcp2T: 24
# thisPCNT: 22
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E5A0>
# instructionVal1NT: 0b10101100000001100000000000000101
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C9E0>
# instructionVal2NT: 0b0
# rs1NT: 0
# rt1NT: 6
# rs2NT: 0
# rt2NT: 0
# pcp2NT: 24
# nextpcT: 24
# nextpcNT: 24
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 25
# readData2_1T: 30
# imm_1T: 0
# rs1T: 6
# rt1T: 7
# rd1T: 6
# thisPCT: 20
# pcp2T: 22
# destreg1T: 6
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DF40>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 6
# rs2T: 0
# rt2T: 7
# rd2T: 0
# destreg2T: 7
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F7A0>
# readData1_1NT: 25
# readData2_1NT: 30
# imm_1NT: 0
# rs1NT: 6
# rt1NT: 7
# rd1NT: 6
# thisPCNT: 20
# pcp2NT: 22
# destreg1NT: 6
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F140>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 6
# rs2NT: 0
# rt2NT: 7
# rd2NT: 0
# destreg2NT: 7
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C6E0>
# instructionVal1T: 0b110001110011000000100110
# instructionVal2T: 0b10101100000001110000000000000110
# instructionVal1NT: 0b110001110011000000100110
# instructionVal2NT: 0b10101100000001110000000000000110
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FAA0>
# instructionVal1: 0b110001110011100000100110
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FC20>
# instructionVal2: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 25
# forwardBres2: 0
# imm_2: 0
# readData1_2: 0
# imm_1: 0
# rs1: 6
# rt1: 7
# rd1: 7
# rs2: 0
# rt2: 0
# rd2: 0
# op1: 7
# op2: 30
# op1_2: 0
# op2_2: 0
# data1: 25
# data2: 0
# thisPC: 18
# destreg1: 7
# destreg2: 0
# pcp2: 20
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E930>
# instructionVal1: 0b10101100000001010000000000000100
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB10>
# instructionVal2: 0b110001110011000000100110
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 1
# pc: 0
# data1: 35
# data2: 7
# rs1: 0
# rt1: 5
# rd1: 0
# rs2: 6
# rt2: 7
# rd2: 6
# thisPC: 16
# destreg1: 5
# destreg2: 6
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 10
# M 3: 5
# M 4: 20
# M 5: 15
# M 6: 25
# M 7: 30
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 10
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 12
# --------------------------------------------------
# PCT: 24
# PCNT: 24
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 1
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 24
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F140>
# instructionVal1T: 0b0
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CDA0>
# instructionVal2T: 0b0
# rs1T: 0
# rt1T: 0
# rs2T: 0
# rt2T: 0
# pcp2T: 26
# thisPCNT: 24
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB10>
# instructionVal1NT: 0b0
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D5E0>
# instructionVal2NT: 0b0
# rs1NT: 0
# rt1NT: 0
# rs2NT: 0
# rt2NT: 0
# pcp2NT: 26
# nextpcT: 26
# nextpcNT: 26
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 0
# readData2_1T: 0
# imm_1T: 5
# rs1T: 0
# rt1T: 6
# rd1T: 0
# thisPCT: 22
# pcp2T: 24
# destreg1T: 6
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CA40>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 0
# rs2T: 0
# rt2T: 0
# rd2T: 0
# destreg2T: 0
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CBF0>
# readData1_1NT: 0
# readData2_1NT: 0
# imm_1NT: 5
# rs1NT: 0
# rt1NT: 6
# rd1NT: 0
# thisPCNT: 22
# pcp2NT: 24
# destreg1NT: 6
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E5A0>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 0
# rs2NT: 0
# rt2NT: 0
# rd2NT: 0
# destreg2NT: 0
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C9E0>
# instructionVal1T: 0b10101100000001100000000000000101
# instructionVal2T: 0b0
# instructionVal1NT: 0b10101100000001100000000000000101
# instructionVal2NT: 0b0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DF40>
# instructionVal1: 0b110001110011000000100110
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F7A0>
# instructionVal2: 0b10101100000001110000000000000110
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 25
# forwardBres2: 0
# imm_2: 6
# readData1_2: 0
# imm_1: 0
# rs1: 6
# rt1: 7
# rd1: 6
# rs2: 0
# rt2: 7
# rd2: 0
# op1: 7
# op2: 25
# op1_2: 0
# op2_2: 6
# data1: 30
# data2: 30
# thisPC: 20
# destreg1: 6
# destreg2: 7
# pcp2: 22
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FAA0>
# instructionVal1: 0b110001110011100000100110
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FC20>
# instructionVal2: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 1
# pc: 0
# data1: 25
# data2: 0
# rs1: 6
# rt1: 7
# rd1: 7
# rs2: 0
# rt2: 0
# rd2: 0
# thisPC: 18
# destreg1: 7
# destreg2: 0
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 10
# M 3: 5
# M 4: 20
# M 5: 15
# M 6: 7
# M 7: 30
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 10
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 13
# --------------------------------------------------
# PCT: 26
# PCNT: 26
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 1
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 26
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB40>
# instructionVal1T: 0b0
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E330>
# instructionVal2T: 0b0
# rs1T: 0
# rt1T: 0
# rs2T: 0
# rt2T: 0
# pcp2T: 28
# thisPCNT: 26
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EE40>
# instructionVal1NT: 0b0
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CF80>
# instructionVal2NT: 0b0
# rs1NT: 0
# rt1NT: 0
# rs2NT: 0
# rt2NT: 0
# pcp2NT: 28
# nextpcT: 28
# nextpcNT: 28
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 1
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 0
# readData2_1T: 0
# imm_1T: 0
# rs1T: 0
# rt1T: 0
# rd1T: 0
# thisPCT: 24
# pcp2T: 26
# destreg1T: 0
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F140>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 0
# rs2T: 0
# rt2T: 0
# rd2T: 0
# destreg2T: 0
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CDA0>
# readData1_1NT: 0
# readData2_1NT: 0
# imm_1NT: 0
# rs1NT: 0
# rt1NT: 0
# rd1NT: 0
# thisPCNT: 24
# pcp2NT: 26
# destreg1NT: 0
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB10>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 0
# rs2NT: 0
# rt2NT: 0
# rd2NT: 0
# destreg2NT: 0
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D5E0>
# instructionVal1T: 0b0
# instructionVal2T: 0b0
# instructionVal1NT: 0b0
# instructionVal2NT: 0b0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CA40>
# instructionVal1: 0b10101100000001100000000000000101
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CBF0>
# instructionVal2: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 0
# forwardBres2: 0
# imm_2: 0
# readData1_2: 0
# imm_1: 5
# rs1: 0
# rt1: 6
# rd1: 0
# rs2: 0
# rt2: 0
# rd2: 0
# op1: 0
# op2: 5
# op1_2: 0
# op2_2: 0
# data1: 7
# data2: 0
# thisPC: 22
# destreg1: 6
# destreg2: 0
# pcp2: 24
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DF40>
# instructionVal1: 0b110001110011000000100110
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F7A0>
# instructionVal2: 0b10101100000001110000000000000110
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 1
# pc: 0
# data1: 30
# data2: 30
# rs1: 6
# rt1: 7
# rd1: 6
# rs2: 0
# rt2: 7
# rd2: 0
# thisPC: 20
# destreg1: 6
# destreg2: 7
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 10
# M 3: 5
# M 4: 20
# M 5: 15
# M 6: 7
# M 7: 25
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 10
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 14
# --------------------------------------------------
# PCT: 28
# PCNT: 28
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 1
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 28
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C440>
# instructionVal1T: 0b0
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CB60>
# instructionVal2T: 0b0
# rs1T: 0
# rt1T: 0
# rs2T: 0
# rt2T: 0
# pcp2T: 30
# thisPCNT: 28
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FB00>
# instructionVal1NT: 0b0
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E240>
# instructionVal2NT: 0b0
# rs1NT: 0
# rt1NT: 0
# rs2NT: 0
# rt2NT: 0
# pcp2NT: 30
# nextpcT: 30
# nextpcNT: 30
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 1
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 0
# readData2_1T: 0
# imm_1T: 0
# rs1T: 0
# rt1T: 0
# rd1T: 0
# thisPCT: 26
# pcp2T: 28
# destreg1T: 0
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB40>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 0
# rs2T: 0
# rt2T: 0
# rd2T: 0
# destreg2T: 0
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E330>
# readData1_1NT: 0
# readData2_1NT: 0
# imm_1NT: 0
# rs1NT: 0
# rt1NT: 0
# rd1NT: 0
# thisPCNT: 26
# pcp2NT: 28
# destreg1NT: 0
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EE40>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 0
# rs2NT: 0
# rt2NT: 0
# rd2NT: 0
# destreg2NT: 0
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CF80>
# instructionVal1T: 0b0
# instructionVal2T: 0b0
# instructionVal1NT: 0b0
# instructionVal2NT: 0b0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F140>
# instructionVal1: 0b0
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CDA0>
# instructionVal2: 0b0
# prediction: 0
# stateIndex: 0
# last: 1
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 0
# forwardBres2: 0
# imm_2: 0
# readData1_2: 0
# imm_1: 0
# rs1: 0
# rt1: 0
# rd1: 0
# rs2: 0
# rt2: 0
# rd2: 0
# op1: 0
# op2: 0
# op1_2: 0
# op2_2: 0
# data1: 0
# data2: 0
# thisPC: 24
# destreg1: 0
# destreg2: 0
# pcp2: 26
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CA40>
# instructionVal1: 0b10101100000001100000000000000101
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CBF0>
# instructionVal2: 0b0
# prediction: 0
# stateIndex: 0
# last: 0
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 1
# pc: 0
# data1: 7
# data2: 0
# rs1: 0
# rt1: 6
# rd1: 0
# rs2: 0
# rt2: 0
# rd2: 0
# thisPC: 22
# destreg1: 6
# destreg2: 0
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 10
# M 3: 5
# M 4: 20
# M 5: 15
# M 6: 30
# M 7: 25
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 10
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 15
# --------------------------------------------------
# PCT: 30
# PCNT: 30
# Taken: 1
# IF_ID:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 1
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FEF0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C830>
# data: 0
# done: 1
# pc: 0
# rs1: 0
# rt1: 0
# rs2: 0
# rt2: 0
# thisPCT: 30
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FAA0>
# instructionVal1T: 0b0
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C8C0>
# instructionVal2T: 0b0
# rs1T: 0
# rt1T: 0
# rs2T: 0
# rt2T: 0
# pcp2T: 32
# thisPCNT: 30
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C350>
# instructionVal1NT: 0b0
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CBF0>
# instructionVal2NT: 0b0
# rs1NT: 0
# rt1NT: 0
# rs2NT: 0
# rt2NT: 0
# pcp2NT: 32
# nextpcT: 32
# nextpcNT: 32
# --------------------
# ID_EX:
#
# flush: 0
# instruction1: 0
# instructionVal1: 0
# instruction2: 0
# instructionVal2: 0
# prediction: 0
# stateIndex: 0
# last: 1
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853DA60>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E720>
# data: 0
# done: 1
# pc: 0
# readData1_1T: 0
# readData2_1T: 0
# imm_1T: 0
# rs1T: 0
# rt1T: 0
# rd1T: 0
# thisPCT: 28
# pcp2T: 30
# destreg1T: 0
# instruction1T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853C440>
# readData1_2T: 0
# readData2_2T: 0
# imm_2T: 0
# rs2T: 0
# rt2T: 0
# rd2T: 0
# destreg2T: 0
# instruction2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CB60>
# readData1_1NT: 0
# readData2_1NT: 0
# imm_1NT: 0
# rs1NT: 0
# rt1NT: 0
# rd1NT: 0
# thisPCNT: 28
# pcp2NT: 30
# destreg1NT: 0
# instruction1NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853FB00>
# readData1_2NT: 0
# readData2_2NT: 0
# imm_2NT: 0
# rs2NT: 0
# rt2NT: 0
# rd2NT: 0
# destreg2NT: 0
# instruction2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E240>
# instructionVal1T: 0b0
# instructionVal2T: 0b0
# instructionVal1NT: 0b0
# instructionVal2NT: 0b0
# --------------------
# EX_MEM:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853EB40>
# instructionVal1: 0b0
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E330>
# instructionVal2: 0b0
# prediction: 0
# stateIndex: 0
# last: 1
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D760>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853D820>
# data: 0
# done: 1
# pc: 0
# forwardBres1: 0
# imm1: 0
# readData1_1: 0
# forwardBres2: 0
# imm_2: 0
# readData1_2: 0
# imm_1: 0
# rs1: 0
# rt1: 0
# rd1: 0
# rs2: 0
# rt2: 0
# rd2: 0
# op1: 0
# op2: 0
# op1_2: 0
# op2_2: 0
# data1: 0
# data2: 0
# thisPC: 26
# destreg1: 0
# destreg2: 0
# pcp2: 28
# --------------------
# MEM_WB:
#
# flush: 0
# instruction1: <__main__.runCpu.<locals>.Instruction object at 0x000002107853F140>
# instructionVal1: 0b0
# instruction2: <__main__.runCpu.<locals>.Instruction object at 0x000002107853CDA0>
# instructionVal2: 0b0
# prediction: 0
# stateIndex: 0
# last: 1
# inst2T: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E6C0>
# inst2NT: <__main__.runCpu.<locals>.Instruction object at 0x000002107853E660>
# data: 0
# done: 1
# pc: 0
# data1: 0
# data2: 0
# rs1: 0
# rt1: 0
# rd1: 0
# rs2: 0
# rt2: 0
# rd2: 0
# thisPC: 24
# destreg1: 0
# destreg2: 0
# --------------------
# --------------------------------------------------
# M 0: 0
# M 1: 0
# M 2: 10
# M 3: 5
# M 4: 20
# M 5: 15
# M 6: 30
# M 7: 25
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 10
# --------------------------------------------------
#
#
# --------------------------------------------------
# Cycle 16
# --------------------------------------------------
# PCT: 32
# PCNT: 32
# Taken: 1
#
# Final Register Values:
# --------------------------------------------------
# R 0: 0
# R 1: 0
# R 2: 10
# R 3: 5
# R 4: 20
# R 5: 15
# R 6: 30
# R 7: 25
# R 8: 0
# R 9: 0
# R10: 0
# R11: 0
# R12: 0
# R13: 0
# R14: 0
# R15: 0
# R16: 0
# R17: 0
# R18: 0
# R19: 0
# R20: 0
# R21: 0
# R22: 0
# R23: 0
# R24: 0
# R25: 0
# R26: 0
# R27: 0
# R28: 0
# R29: 0
# R30: 0
# R31: 10
# --------------------------------------------------
#
#
# Final mem values:
# --------------------------------------------------
# M 0: 0
# M 1: 10
# M 2: 5
# M 3: 20
# M 4: 15
# M 5: 30
# M 6: 25
# M 7: 0
# M 8: 0
# M 9: 0
# M10: 0
# M11: 0
# M12: 0
# M13: 0
# M14: 0
# M15: 0
# M16: 0
# M17: 0
# M18: 0
# M19: 0
# M20: 0
# M21: 0
# M22: 0
# M23: 0
# M24: 0
# M25: 0
# M26: 0
# M27: 0
# M28: 0
# M29: 0
# M30: 0
# M31: 0
# --------------------------------------------------
# cycle count:  16
# ld hazard count:  0
# branch flush count:  0
# branch instruction count:  0
